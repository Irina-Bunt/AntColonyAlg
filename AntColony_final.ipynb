# %%
import os
import vrplib
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
files = np.unique(['P/'+x[:-4] for x in os.listdir('P')])
files = np.concatenate((files, np.unique(['B/'+x[:-4] for x in os.listdir('B')])))
files = np.concatenate((files, np.unique(['E/'+x[:-4] for x in os.listdir('E')])))

# %%
import vrplib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
font = {
    'family': 'arial',
    'weight': 'bold',
    'size': 15
}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (10, 8)


class ACOUnifiedVRP:
    """
    Объединённая версия алгоритма муравьиной колонии для VRP,
    использующая библиотеку vrplib и гиперпараметры/обновления феромонов
    из 'версии 2'.
    """

    def __init__(self,
                 alpha=0.1,      # Коэффициент для локального/глобального обновления феромонов
                 beta=0.95,      # Коэффициент влияния расстояния (жадность по расстоянию)
                 q0=1.0,         # Порог для жёсткого выбора (детерминированно vs рандомайзер)
                 epochs=4,       # Количество эпох (итераций)
                 num_ants=20,    # Количество муравьёв
                 W=1):           # Добавочная константа для расчёта L_nn
        self.alpha = alpha
        self.beta = beta
        self.q0 = q0
        self.epochs = epochs
        self.num_ants = num_ants
        self.W = W

        self.best_cost = float('inf')
        self.best_route = None

        self.cost = None
        self.routes = None
        self.dist_matrix = None
        self.demand = None
        self.capacity = None
        self.n_customers = None
        self.feromones = None
        self.tau_0 = None

    def fit(self, vrp_file_prefix, verbose=False):
        instance = vrplib.read_instance(f"{vrp_file_prefix}.vrp")
        solution = vrplib.read_solution(f"{vrp_file_prefix}.sol")

        self.cost = solution["cost"]
        self.routes = solution["routes"]

        dimension = instance["dimension"]  
        self.dist_matrix = np.array(instance["edge_weight"])
        self.demand = instance["demand"] 
        self.capacity = instance["capacity"]
        self.n_customers = dimension - 1
        
        min_dist = np.inf
        for i in range(dimension):
            for j in range(dimension):
                d = self.dist_matrix[i, j]
                if 0 < d < min_dist:
                    min_dist = d

        L_nn = (self.n_customers + 1) * min_dist + self.W
        self.tau_0 = 1.0 / L_nn
        self.feromones = np.ones((dimension, dimension)) * self.tau_0

        for epoch in range(self.epochs):
            for _ in range(self.num_ants):
                route, route_cost = self.construct_ant_solution()

                self.local_update(route)

                if route_cost < self.best_cost:
                    self.best_cost = route_cost
                    self.best_route = route

            self.global_update(self.best_route)

            # if verbose:
                # print(f"Epoch {epoch+1}/{self.epochs}, best cost so far: {self.best_cost:.2f}")

    def construct_ant_solution(self):
        route = [0]
        visited = set([0])
        total_cost = 0.0
        curr_capacity = self.capacity
        dimension = self.dist_matrix.shape[0]

        while len(visited) < dimension:
            current_node = route[-1]

            if current_node == 0:
                curr_capacity = self.capacity

            distances = self.dist_matrix[current_node]      
            pher = self.feromones[current_node]             

            attraction = np.zeros(dimension, dtype=float)
            for j in range(dimension):
                d = distances[j]
                if d > 0:
                    attraction[j] = (1 / d) ** self.beta
                else:
                    attraction[j] = 0

            for v in visited:
                attraction[v] = 0.0

            combined = pher * attraction
            sum_combined = combined.sum()

            if sum_combined == 0:
                if current_node != 0:
                    next_node = 0
                else:
                    break
            else:
                probs = combined / sum_combined

                if np.random.rand() < self.q0:
                    next_node = np.argmax(probs)
                else:
                    next_node = np.random.choice(range(dimension), p=probs)

            if next_node != 0:
                if self.demand[next_node] > curr_capacity:
                    next_node = 0

            dist_move = self.dist_matrix[current_node, next_node]
            total_cost += dist_move
            route.append(next_node)

            if next_node != 0:
                visited.add(next_node)
                curr_capacity -= self.demand[next_node]

            if len(visited) == dimension:
                if route[-1] != 0:
                    route.append(0)
                    total_cost += self.dist_matrix[route[-2], 0]
                break

        if route[-1] != 0:
            route.append(0)
            total_cost += self.dist_matrix[route[-2], 0]

        return route, total_cost

    def local_update(self, route):
        for i in range(len(route) - 1):
            a = route[i]
            b = route[i+1]
            self.feromones[a, b] = (1 - self.alpha) * self.feromones[a, b] + self.alpha * self.tau_0

    def global_update(self, best_route):
        if not best_route or len(best_route) < 2 or self.best_cost == float('inf'):
            return

        for i in range(len(best_route) - 1):
            a = best_route[i]
            b = best_route[i+1]
            self.feromones[a, b] = (1 - self.alpha) * self.feromones[a, b] + \
                                   self.alpha * (1.0 / self.best_cost)

    def get_best_solution(self):
        return self.best_route, self.best_cost

    def evaluate_solution(self):
        if self.cost is None or self.cost == 0:
            return None
        improvement = self.best_cost - self.cost
        rel_error = improvement / self.cost
        return rel_error

    def plot_routes(self):
        """
        Вспомогательная функция для визуализации эталонного и найденного маршрута.
        Требует, чтобы в instance['coordinates'] были координаты каждой вершины.
        В некоторых форматах VRP они могут отсутствовать.
        """
        pass
        # coords = instance["coordinates"] 
        # if not coords:
        #     print("No coordinates in instance for plotting.")
        #     return
        #
        # routes = self.routes 
        # self._plot_one_solution(coords, routes, "Bench Solution")
        #
        # if self.best_route:
        #     self._plot_one_solution(coords, [self.best_route], "Our Best Solution")

    def _plot_one_solution(self, coords, routes, title="Solution"):
        plt.figure()
        plt.title(title)
        for r_idx, route in enumerate(routes):
            x_coords = [coords[v][0] for v in route]
            y_coords = [coords[v][1] for v in route]
            plt.plot(x_coords, y_coords, marker='o', label=f"Route {r_idx+1}")
        plt.legend()
        plt.show()

# %%
differences = []
for prefix in files:
    print(f"\nЗапуск муравьиного алгоритма для: {prefix}")

    aco = ACOUnifiedVRP(
        alpha=0.3,  
        beta=5, 
        q0=0.7,  
        epochs=50,  
        num_ants=20,
        W=20
    )

    aco.fit(prefix, verbose=True)

    best_route, best_cost = aco.get_best_solution()

    rel_error = aco.evaluate_solution()
    differences.append(rel_error)
    
    # print(f"Лучший маршрут:  {best_route}")
    print(f"Стоимость:       {best_cost:.2f}")
    if rel_error is not None:
        print(f"Отклонение от эталона: {rel_error * 100:.2f}%")

    aco.plot_routes()
print(np.mean(differences))
# Out:
# Запуск муравьиного алгоритма для: P/P-n101-k4
# Стоимость:       814.54
# Отклонение от эталона: 19.61%
#
# Запуск муравьиного алгоритма для: P/P-n16-k8
# Стоимость:       459.46
# Отклонение от эталона: 2.10%
#
# Запуск муравьиного алгоритма для: P/P-n19-k2
# Стоимость:       228.87
# Отклонение от эталона: 7.96%
#
# Запуск муравьиного алгоритма для: P/P-n20-k2
# Стоимость:       229.86
# Отклонение от эталона: 6.42%
#
# Запуск муравьиного алгоритма для: P/P-n21-k2
# Стоимость:       222.79
# Отклонение от эталона: 5.59%
#
# Запуск муравьиного алгоритма для: P/P-n22-k2
# Стоимость:       224.65
# Отклонение от эталона: 4.00%
#
# Запуск муравьиного алгоритма для: P/P-n22-k8
# Стоимость:       631.89
# Отклонение от эталона: 4.79%
#
# Запуск муравьиного алгоритма для: P/P-n23-k8
# Стоимость:       554.25
# Отклонение от эталона: 4.77%
#
# Запуск муравьиного алгоритма для: P/P-n40-k5
# Стоимость:       530.06
# Отклонение от эталона: 15.73%
#
# Запуск муравьиного алгоритма для: P/P-n45-k5
# Стоимость:       585.13
# Отклонение от эталона: 14.73%
#
# Запуск муравьиного алгоритма для: P/P-n50-k10
# Стоимость:       771.15
# Отклонение от эталона: 10.80%
#
# Запуск муравьиного алгоритма для: P/P-n50-k7
# Стоимость:       620.13
# Отклонение от эталона: 11.94%
#
# Запуск муравьиного алгоритма для: P/P-n50-k8
# Стоимость:       699.89
# Отклонение от эталона: 10.92%
#
# Запуск муравьиного алгоритма для: P/P-n51-k10
# Стоимость:       829.33
# Отклонение от эталона: 11.92%
#
# Запуск муравьиного алгоритма для: P/P-n55-k10
# Стоимость:       750.61
# Отклонение от эталона: 8.16%
#
# Запуск муравьиного алгоритма для: P/P-n55-k15
# Стоимость:       1042.15
# Отклонение от эталона: 5.37%
#
# Запуск муравьиного алгоритма для: P/P-n55-k7
# Стоимость:       643.58
# Отклонение от эталона: 13.31%
#
# Запуск муравьиного алгоритма для: P/P-n55-k8
# Стоимость:       641.47
# Отклонение от эталона: 9.09%
#
# Запуск муравьиного алгоритма для: P/P-n60-k10
# Стоимость:       847.18
# Отклонение от эталона: 13.87%
#
# Запуск муравьиного алгоритма для: P/P-n60-k15
# Стоимость:       1066.90
# Отклонение от эталона: 10.22%
#
# Запуск муравьиного алгоритма для: P/P-n65-k10
# Стоимость:       899.54
# Отклонение от эталона: 13.58%
#
# Запуск муравьиного алгоритма для: P/P-n70-k10
# Стоимость:       943.02
# Отклонение от эталона: 14.03%
#
# Запуск муравьиного алгоритма для: P/P-n76-k4
# Стоимость:       685.71
# Отклонение от эталона: 15.63%
#
# Запуск муравьиного алгоритма для: P/P-n76-k5
# Стоимость:       732.56
# Отклонение от эталона: 16.83%
#
# Запуск муравьиного алгоритма для: B/B-n31-k5
# Стоимость:       682.37
# Отклонение от эталона: 1.54%
#
# Запуск муравьиного алгоритма для: B/B-n34-k5
# Стоимость:       839.54
# Отклонение от эталона: 6.54%
#
# Запуск муравьиного алгоритма для: B/B-n35-k5
# Стоимость:       1020.91
# Отклонение от эталона: 6.90%
#
# Запуск муравьиного алгоритма для: B/B-n38-k6
# Стоимость:       852.32
# Отклонение от эталона: 5.88%
#
# Запуск муравьиного алгоритма для: B/B-n39-k5
# Стоимость:       635.72
# Отклонение от эталона: 15.80%
#
# Запуск муравьиного алгоритма для: B/B-n41-k6
# Стоимость:       911.02
# Отклонение от эталона: 9.89%
#
# Запуск муравьиного алгоритма для: B/B-n43-k6
# Стоимость:       818.12
# Отклонение от эталона: 10.26%
#
# Запуск муравьиного алгоритма для: B/B-n44-k7
# Стоимость:       987.28
# Отклонение от эталона: 8.61%
#
# Запуск муравьиного алгоритма для: B/B-n45-k5
# Стоимость:       815.33
# Отклонение от эталона: 8.57%
#
# Запуск муравьиного алгоритма для: B/B-n45-k6
# Стоимость:       766.76
# Отклонение от эталона: 13.09%
#
# Запуск муравьиного алгоритма для: B/B-n50-k7
# Стоимость:       821.38
# Отклонение от эталона: 10.85%
#
# Запуск муравьиного алгоритма для: B/B-n50-k8
# Стоимость:       1400.35
# Отклонение от эталона: 6.73%
#
# Запуск муравьиного алгоритма для: B/B-n51-k7
# Стоимость:       1084.86
# Отклонение от эталона: 5.12%
#
# Запуск муравьиного алгоритма для: B/B-n52-k7
# Стоимость:       813.57
# Отклонение от эталона: 8.91%
#
# Запуск муравьиного алгоритма для: B/B-n56-k7
# Стоимость:       830.99
# Отклонение от эталона: 17.54%
#
# Запуск муравьиного алгоритма для: B/B-n57-k7
# Стоимость:       1225.14
# Отклонение от эталона: 6.26%
#
# Запуск муравьиного алгоритма для: B/B-n57-k9
# Стоимость:       1693.08
# Отклонение от эталона: 5.95%
#
# Запуск муравьиного алгоритма для: B/B-n63-k10
# Стоимость:       1645.45
# Отклонение от эталона: 9.99%
#
# Запуск муравьиного алгоритма для: B/B-n64-k9
# Стоимость:       960.60
# Отклонение от эталона: 11.57%
#
# Запуск муравьиного алгоритма для: B/B-n66-k9
# Стоимость:       1405.91
# Отклонение от эталона: 6.83%
#
# Запуск муравьиного алгоритма для: B/B-n67-k10
# Стоимость:       1120.95
# Отклонение от эталона: 8.62%
#
# Запуск муравьиного алгоритма для: B/B-n68-k9
# Стоимость:       1369.75
# Отклонение от эталона: 7.68%
#
# Запуск муравьиного алгоритма для: B/B-n78-k10
# Стоимость:       1324.22
# Отклонение от эталона: 8.45%
#
# Запуск муравьиного алгоритма для: E/E-n101-k14
# Стоимость:       1263.24
# Отклонение от эталона: 18.39%
#
# Запуск муравьиного алгоритма для: E/E-n101-k8
# Стоимость:       1000.57
# Отклонение от эталона: 22.77%
#
# Запуск муравьиного алгоритма для: E/E-n13-k4
# Стоимость:       300.00
# Отклонение от эталона: 21.46%
#
# Запуск муравьиного алгоритма для: E/E-n22-k4
# Стоимость:       393.95
# Отклонение от эталона: 5.05%
#
# Запуск муравьиного алгоритма для: E/E-n23-k3
# Стоимость:       588.35
# Отклонение от эталона: 3.40%
#
# Запуск муравьиного алгоритма для: E/E-n30-k3
# Стоимость:       540.02
# Отклонение от эталона: 1.13%
#
# Запуск муравьиного алгоритма для: E/E-n31-k7
# Стоимость:       1316.00
# Отклонение от эталона: 247.23%
#
# Запуск муравьиного алгоритма для: E/E-n33-k4
# Стоимость:       883.30
# Отклонение от эталона: 5.78%
#
# Запуск муравьиного алгоритма для: E/E-n51-k5
# Стоимость:       634.88
# Отклонение от эталона: 21.86%
#
# Запуск муравьиного алгоритма для: E/E-n76-k10
# Стоимость:       958.09
# Отклонение от эталона: 15.43%
#
# Запуск муравьиного алгоритма для: E/E-n76-k14
# Стоимость:       1145.65
# Отклонение от эталона: 12.21%
#
# Запуск муравьиного алгоритма для: E/E-n76-k7
# Стоимость:       798.40
# Отклонение от эталона: 17.07%
#
# Запуск муравьиного алгоритма для: E/E-n76-k8
# Стоимость:       834.97
# Отклонение от эталона: 13.60%
# 0.14305703860716484

# %%
q0 = [0.3, 0.4, 0.5, 0.7, 0.9]
alpha = [0.3, 0.5, 0.6, 0.7, 0.8, 0.9]
beta = [1, 2]
epochs=[4, 10]
W = [1, 10, 100]
ants = [4, 10]

scores = dict()
for a in alpha:
    for b in beta:
        for q in q0:
            for e in epochs:
                for an in ants:
                    for w in W:
                        differences = []
                        for prefix in files:
                            aco = ACOUnifiedVRP(
                                alpha=a,  
                                beta=b, 
                                q0=q,  
                                epochs=e,  
                                num_ants=an,
                                W=w
                            )
                            aco.fit(prefix, verbose=True)
                            rel_error = aco.evaluate_solution()
                            differences.append(rel_error)
                        scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'] = np.mean(differences)
                        print(scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'], f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}')
# Out:
# 0.6913978342973425 alpha=0.3 beta=1 q0=0.3 epochs=4 ants=4 W=1
# 0.6728508535289923 alpha=0.3 beta=1 q0=0.3 epochs=4 ants=4 W=10
# 0.6988594312991191 alpha=0.3 beta=1 q0=0.3 epochs=4 ants=4 W=100
# 0.6190470089724102 alpha=0.3 beta=1 q0=0.3 epochs=4 ants=10 W=1
# 0.62351349376214 alpha=0.3 beta=1 q0=0.3 epochs=4 ants=10 W=10
# 0.631167897025073 alpha=0.3 beta=1 q0=0.3 epochs=4 ants=10 W=100
# 0.6403575799496554 alpha=0.3 beta=1 q0=0.3 epochs=10 ants=4 W=1
# 0.6362059828050127 alpha=0.3 beta=1 q0=0.3 epochs=10 ants=4 W=10
# 0.6274105275260415 alpha=0.3 beta=1 q0=0.3 epochs=10 ants=4 W=100
# 0.5770050499491692 alpha=0.3 beta=1 q0=0.3 epochs=10 ants=10 W=1
# 0.5665947481990811 alpha=0.3 beta=1 q0=0.3 epochs=10 ants=10 W=10
# 0.5821026780591121 alpha=0.3 beta=1 q0=0.3 epochs=10 ants=10 W=100
# 0.5942000610669386 alpha=0.3 beta=1 q0=0.4 epochs=4 ants=4 W=1
# 0.5998789808348508 alpha=0.3 beta=1 q0=0.4 epochs=4 ants=4 W=10
# 0.6000917549918543 alpha=0.3 beta=1 q0=0.4 epochs=4 ants=4 W=100
# 0.5302699480909445 alpha=0.3 beta=1 q0=0.4 epochs=4 ants=10 W=1
# 0.536140743502415 alpha=0.3 beta=1 q0=0.4 epochs=4 ants=10 W=10
# 0.543886059791458 alpha=0.3 beta=1 q0=0.4 epochs=4 ants=10 W=100
# 0.546451778301292 alpha=0.3 beta=1 q0=0.4 epochs=10 ants=4 W=1
# 0.557519018827524 alpha=0.3 beta=1 q0=0.4 epochs=10 ants=4 W=10
# 0.5605383895071523 alpha=0.3 beta=1 q0=0.4 epochs=10 ants=4 W=100
# 0.49153933497007934 alpha=0.3 beta=1 q0=0.4 epochs=10 ants=10 W=1
# 0.49516167614579154 alpha=0.3 beta=1 q0=0.4 epochs=10 ants=10 W=10
# 0.5055182590353383 alpha=0.3 beta=1 q0=0.4 epochs=10 ants=10 W=100
# 0.5093126632727436 alpha=0.3 beta=1 q0=0.5 epochs=4 ants=4 W=1
# 0.49815924995081323 alpha=0.3 beta=1 q0=0.5 epochs=4 ants=4 W=10
# 0.5037125514038517 alpha=0.3 beta=1 q0=0.5 epochs=4 ants=4 W=100
# 0.4588574315426872 alpha=0.3 beta=1 q0=0.5 epochs=4 ants=10 W=1
# 0.4578965625447135 alpha=0.3 beta=1 q0=0.5 epochs=4 ants=10 W=10
# 0.4432688503894661 alpha=0.3 beta=1 q0=0.5 epochs=4 ants=10 W=100
# 0.4899669867721654 alpha=0.3 beta=1 q0=0.5 epochs=10 ants=4 W=1
# 0.4703866233378368 alpha=0.3 beta=1 q0=0.5 epochs=10 ants=4 W=10
# 0.4624893867838183 alpha=0.3 beta=1 q0=0.5 epochs=10 ants=4 W=100
# 0.41567379974230134 alpha=0.3 beta=1 q0=0.5 epochs=10 ants=10 W=1
# 0.4297307185272004 alpha=0.3 beta=1 q0=0.5 epochs=10 ants=10 W=10
# 0.4270382734580622 alpha=0.3 beta=1 q0=0.5 epochs=10 ants=10 W=100
# 0.3509090335071114 alpha=0.3 beta=1 q0=0.7 epochs=4 ants=4 W=1
# 0.3560834212227649 alpha=0.3 beta=1 q0=0.7 epochs=4 ants=4 W=10
# 0.366684852951898 alpha=0.3 beta=1 q0=0.7 epochs=4 ants=4 W=100
# 0.31429571667811806 alpha=0.3 beta=1 q0=0.7 epochs=4 ants=10 W=1
# 0.32156457731744226 alpha=0.3 beta=1 q0=0.7 epochs=4 ants=10 W=10
# 0.314213886103009 alpha=0.3 beta=1 q0=0.7 epochs=4 ants=10 W=100
# 0.34479140954256976 alpha=0.3 beta=1 q0=0.7 epochs=10 ants=4 W=1
# 0.3417494734249512 alpha=0.3 beta=1 q0=0.7 epochs=10 ants=4 W=10
# 0.33361781768986215 alpha=0.3 beta=1 q0=0.7 epochs=10 ants=4 W=100
# 0.3009016665694343 alpha=0.3 beta=1 q0=0.7 epochs=10 ants=10 W=1
# 0.2870590520082834 alpha=0.3 beta=1 q0=0.7 epochs=10 ants=10 W=10
# 0.28126874703921756 alpha=0.3 beta=1 q0=0.7 epochs=10 ants=10 W=100
# 0.2463653861583871 alpha=0.3 beta=1 q0=0.9 epochs=4 ants=4 W=1
# 0.2531845467218564 alpha=0.3 beta=1 q0=0.9 epochs=4 ants=4 W=10
# 0.2382859139963945 alpha=0.3 beta=1 q0=0.9 epochs=4 ants=4 W=100
# 0.21638434925504194 alpha=0.3 beta=1 q0=0.9 epochs=4 ants=10 W=1
# 0.21249316239661514 alpha=0.3 beta=1 q0=0.9 epochs=4 ants=10 W=10
# 0.21808885540760017 alpha=0.3 beta=1 q0=0.9 epochs=4 ants=10 W=100
# 0.23404119199654128 alpha=0.3 beta=1 q0=0.9 epochs=10 ants=4 W=1
# 0.23152548348220586 alpha=0.3 beta=1 q0=0.9 epochs=10 ants=4 W=10
# 0.2253076869967256 alpha=0.3 beta=1 q0=0.9 epochs=10 ants=4 W=100
# 0.2128691286810365 alpha=0.3 beta=1 q0=0.9 epochs=10 ants=10 W=1
# 0.20800136874358646 alpha=0.3 beta=1 q0=0.9 epochs=10 ants=10 W=10
# 0.20540310338432202 alpha=0.3 beta=1 q0=0.9 epochs=10 ants=10 W=100
# 0.39623627413847096 alpha=0.3 beta=2 q0=0.3 epochs=4 ants=4 W=1
# 0.4115935459142023 alpha=0.3 beta=2 q0=0.3 epochs=4 ants=4 W=10
# 0.39977083315969913 alpha=0.3 beta=2 q0=0.3 epochs=4 ants=4 W=100
# 0.3627307129015064 alpha=0.3 beta=2 q0=0.3 epochs=4 ants=10 W=1
# 0.35606256458809915 alpha=0.3 beta=2 q0=0.3 epochs=4 ants=10 W=10
# 0.3662880085315694 alpha=0.3 beta=2 q0=0.3 epochs=4 ants=10 W=100
# 0.3716247020873676 alpha=0.3 beta=2 q0=0.3 epochs=10 ants=4 W=1
# 0.38362044295337333 alpha=0.3 beta=2 q0=0.3 epochs=10 ants=4 W=10
# 0.37827186913773514 alpha=0.3 beta=2 q0=0.3 epochs=10 ants=4 W=100
# 0.34114636882710847 alpha=0.3 beta=2 q0=0.3 epochs=10 ants=10 W=1
# 0.3442212715961475 alpha=0.3 beta=2 q0=0.3 epochs=10 ants=10 W=10
# 0.3424772565327446 alpha=0.3 beta=2 q0=0.3 epochs=10 ants=10 W=100
# 0.3585038062273487 alpha=0.3 beta=2 q0=0.4 epochs=4 ants=4 W=1
# 0.3698127635237168 alpha=0.3 beta=2 q0=0.4 epochs=4 ants=4 W=10
# 0.3742009771396911 alpha=0.3 beta=2 q0=0.4 epochs=4 ants=4 W=100
# 0.33535870080976776 alpha=0.3 beta=2 q0=0.4 epochs=4 ants=10 W=1
# 0.3311455727831783 alpha=0.3 beta=2 q0=0.4 epochs=4 ants=10 W=10
# 0.3209175574310958 alpha=0.3 beta=2 q0=0.4 epochs=4 ants=10 W=100
# 0.33611869355395657 alpha=0.3 beta=2 q0=0.4 epochs=10 ants=4 W=1
# 0.3407282005340234 alpha=0.3 beta=2 q0=0.4 epochs=10 ants=4 W=10
# 0.33759742217634237 alpha=0.3 beta=2 q0=0.4 epochs=10 ants=4 W=100
# 0.30872608692157216 alpha=0.3 beta=2 q0=0.4 epochs=10 ants=10 W=1
# 0.31475678586784733 alpha=0.3 beta=2 q0=0.4 epochs=10 ants=10 W=10
# 0.29826122471735456 alpha=0.3 beta=2 q0=0.4 epochs=10 ants=10 W=100
# 0.337008904139615 alpha=0.3 beta=2 q0=0.5 epochs=4 ants=4 W=1
# 0.3380092395940299 alpha=0.3 beta=2 q0=0.5 epochs=4 ants=4 W=10
# 0.3266507453444579 alpha=0.3 beta=2 q0=0.5 epochs=4 ants=4 W=100
# 0.2960336176336659 alpha=0.3 beta=2 q0=0.5 epochs=4 ants=10 W=1
# 0.29150387998432564 alpha=0.3 beta=2 q0=0.5 epochs=4 ants=10 W=10
# 0.28913358496508473 alpha=0.3 beta=2 q0=0.5 epochs=4 ants=10 W=100
# 0.30254491074228057 alpha=0.3 beta=2 q0=0.5 epochs=10 ants=4 W=1
# 0.3054380254860221 alpha=0.3 beta=2 q0=0.5 epochs=10 ants=4 W=10
# 0.30464270944010374 alpha=0.3 beta=2 q0=0.5 epochs=10 ants=4 W=100
# 0.2769701335166685 alpha=0.3 beta=2 q0=0.5 epochs=10 ants=10 W=1
# 0.27074797504739767 alpha=0.3 beta=2 q0=0.5 epochs=10 ants=10 W=10
# 0.2768552472095756 alpha=0.3 beta=2 q0=0.5 epochs=10 ants=10 W=100
# 0.27235942832787735 alpha=0.3 beta=2 q0=0.7 epochs=4 ants=4 W=1
# 0.2685815420272413 alpha=0.3 beta=2 q0=0.7 epochs=4 ants=4 W=10
# 0.2693872589260295 alpha=0.3 beta=2 q0=0.7 epochs=4 ants=4 W=100
# 0.24205433377589397 alpha=0.3 beta=2 q0=0.7 epochs=4 ants=10 W=1
# 0.24550171615470187 alpha=0.3 beta=2 q0=0.7 epochs=4 ants=10 W=10
# 0.24427562768105002 alpha=0.3 beta=2 q0=0.7 epochs=4 ants=10 W=100
# 0.24866743147995432 alpha=0.3 beta=2 q0=0.7 epochs=10 ants=4 W=1
# 0.24795900952060165 alpha=0.3 beta=2 q0=0.7 epochs=10 ants=4 W=10
# 0.24507463530575882 alpha=0.3 beta=2 q0=0.7 epochs=10 ants=4 W=100
# 0.22003574419424676 alpha=0.3 beta=2 q0=0.7 epochs=10 ants=10 W=1
# 0.22558399905467727 alpha=0.3 beta=2 q0=0.7 epochs=10 ants=10 W=10
# 0.21820348696513564 alpha=0.3 beta=2 q0=0.7 epochs=10 ants=10 W=100
# 0.22013782035657095 alpha=0.3 beta=2 q0=0.9 epochs=4 ants=4 W=1
# 0.22957678002436135 alpha=0.3 beta=2 q0=0.9 epochs=4 ants=4 W=10
# 0.22010489370847797 alpha=0.3 beta=2 q0=0.9 epochs=4 ants=4 W=100
# 0.1988456134278815 alpha=0.3 beta=2 q0=0.9 epochs=4 ants=10 W=1
# 0.20062745049417566 alpha=0.3 beta=2 q0=0.9 epochs=4 ants=10 W=10
# 0.2018104193201796 alpha=0.3 beta=2 q0=0.9 epochs=4 ants=10 W=100
# 0.20616977177847579 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=4 W=1
# 0.20486791632396517 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=4 W=10
# 0.2029649931669379 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=4 W=100
# 0.18435543032666538 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.1883128247343851 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.19146080933443133 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.6682541488613235 alpha=0.5 beta=1 q0=0.3 epochs=4 ants=4 W=1
# 0.6704955772364346 alpha=0.5 beta=1 q0=0.3 epochs=4 ants=4 W=10
# 0.6970616558413822 alpha=0.5 beta=1 q0=0.3 epochs=4 ants=4 W=100
# 0.6262052339797364 alpha=0.5 beta=1 q0=0.3 epochs=4 ants=10 W=1
# 0.6286742838143279 alpha=0.5 beta=1 q0=0.3 epochs=4 ants=10 W=10
# 0.6319801316867315 alpha=0.5 beta=1 q0=0.3 epochs=4 ants=10 W=100
# 0.6366902114597085 alpha=0.5 beta=1 q0=0.3 epochs=10 ants=4 W=1
# 0.6475875072775725 alpha=0.5 beta=1 q0=0.3 epochs=10 ants=4 W=10
# 0.6278741401357646 alpha=0.5 beta=1 q0=0.3 epochs=10 ants=4 W=100
# 0.5800233358423824 alpha=0.5 beta=1 q0=0.3 epochs=10 ants=10 W=1
# 0.5854521672088537 alpha=0.5 beta=1 q0=0.3 epochs=10 ants=10 W=10
# 0.5829632786143021 alpha=0.5 beta=1 q0=0.3 epochs=10 ants=10 W=100
# 0.5938838784917687 alpha=0.5 beta=1 q0=0.4 epochs=4 ants=4 W=1
# 0.5985518774176419 alpha=0.5 beta=1 q0=0.4 epochs=4 ants=4 W=10
# 0.5712649712540715 alpha=0.5 beta=1 q0=0.4 epochs=4 ants=4 W=100
# 0.5324279119606957 alpha=0.5 beta=1 q0=0.4 epochs=4 ants=10 W=1
# 0.5445652043091151 alpha=0.5 beta=1 q0=0.4 epochs=4 ants=10 W=10
# 0.5446092373426387 alpha=0.5 beta=1 q0=0.4 epochs=4 ants=10 W=100
# 0.5677223975843693 alpha=0.5 beta=1 q0=0.4 epochs=10 ants=4 W=1
# 0.5669363800433381 alpha=0.5 beta=1 q0=0.4 epochs=10 ants=4 W=10
# 0.5552207855251985 alpha=0.5 beta=1 q0=0.4 epochs=10 ants=4 W=100
# 0.5094786418396885 alpha=0.5 beta=1 q0=0.4 epochs=10 ants=10 W=1
# 0.498701093877941 alpha=0.5 beta=1 q0=0.4 epochs=10 ants=10 W=10
# 0.4939856902841145 alpha=0.5 beta=1 q0=0.4 epochs=10 ants=10 W=100
# 0.5320168218527103 alpha=0.5 beta=1 q0=0.5 epochs=4 ants=4 W=1
# 0.5207365633774989 alpha=0.5 beta=1 q0=0.5 epochs=4 ants=4 W=10
# 0.5087649307739756 alpha=0.5 beta=1 q0=0.5 epochs=4 ants=4 W=100
# 0.47468153189789797 alpha=0.5 beta=1 q0=0.5 epochs=4 ants=10 W=1
# 0.468835759760043 alpha=0.5 beta=1 q0=0.5 epochs=4 ants=10 W=10
# 0.4765745028108157 alpha=0.5 beta=1 q0=0.5 epochs=4 ants=10 W=100
# 0.48407643737076383 alpha=0.5 beta=1 q0=0.5 epochs=10 ants=4 W=1
# 0.4811132221656339 alpha=0.5 beta=1 q0=0.5 epochs=10 ants=4 W=10
# 0.47413535793993533 alpha=0.5 beta=1 q0=0.5 epochs=10 ants=4 W=100
# 0.4383474062973489 alpha=0.5 beta=1 q0=0.5 epochs=10 ants=10 W=1
# 0.4372563678563436 alpha=0.5 beta=1 q0=0.5 epochs=10 ants=10 W=10
# 0.4353917915068464 alpha=0.5 beta=1 q0=0.5 epochs=10 ants=10 W=100
# 0.36975764907944153 alpha=0.5 beta=1 q0=0.7 epochs=4 ants=4 W=1
# 0.3691502666063469 alpha=0.5 beta=1 q0=0.7 epochs=4 ants=4 W=10
# 0.37317042491681984 alpha=0.5 beta=1 q0=0.7 epochs=4 ants=4 W=100
# 0.3311106561976587 alpha=0.5 beta=1 q0=0.7 epochs=4 ants=10 W=1
# 0.32893927869128503 alpha=0.5 beta=1 q0=0.7 epochs=4 ants=10 W=10
# 0.3182700733808704 alpha=0.5 beta=1 q0=0.7 epochs=4 ants=10 W=100
# 0.35112630323539934 alpha=0.5 beta=1 q0=0.7 epochs=10 ants=4 W=1
# 0.35499187475886174 alpha=0.5 beta=1 q0=0.7 epochs=10 ants=4 W=10
# 0.3415152648069589 alpha=0.5 beta=1 q0=0.7 epochs=10 ants=4 W=100
# 0.30627994208393794 alpha=0.5 beta=1 q0=0.7 epochs=10 ants=10 W=1
# 0.3132997673846089 alpha=0.5 beta=1 q0=0.7 epochs=10 ants=10 W=10
# 0.29966085404458287 alpha=0.5 beta=1 q0=0.7 epochs=10 ants=10 W=100
# 0.25802354582970355 alpha=0.5 beta=1 q0=0.9 epochs=4 ants=4 W=1
# 0.24825761312686156 alpha=0.5 beta=1 q0=0.9 epochs=4 ants=4 W=10
# 0.24897741571866447 alpha=0.5 beta=1 q0=0.9 epochs=4 ants=4 W=100
# 0.2205164985916438 alpha=0.5 beta=1 q0=0.9 epochs=4 ants=10 W=1
# 0.22437171827741037 alpha=0.5 beta=1 q0=0.9 epochs=4 ants=10 W=10
# 0.2203523307105257 alpha=0.5 beta=1 q0=0.9 epochs=4 ants=10 W=100
# 0.24738372746306564 alpha=0.5 beta=1 q0=0.9 epochs=10 ants=4 W=1
# 0.2472006265281765 alpha=0.5 beta=1 q0=0.9 epochs=10 ants=4 W=10
# 0.22687596121212797 alpha=0.5 beta=1 q0=0.9 epochs=10 ants=4 W=100
# 0.21481896234197556 alpha=0.5 beta=1 q0=0.9 epochs=10 ants=10 W=1
# 0.21712976840937442 alpha=0.5 beta=1 q0=0.9 epochs=10 ants=10 W=10
# 0.217838499839434 alpha=0.5 beta=1 q0=0.9 epochs=10 ants=10 W=100
# 0.41353385154549005 alpha=0.5 beta=2 q0=0.3 epochs=4 ants=4 W=1
# 0.420024091837801 alpha=0.5 beta=2 q0=0.3 epochs=4 ants=4 W=10
# 0.41411832192755216 alpha=0.5 beta=2 q0=0.3 epochs=4 ants=4 W=100
# 0.37401915751437953 alpha=0.5 beta=2 q0=0.3 epochs=4 ants=10 W=1
# 0.36855060126218586 alpha=0.5 beta=2 q0=0.3 epochs=4 ants=10 W=10
# 0.3755500837797182 alpha=0.5 beta=2 q0=0.3 epochs=4 ants=10 W=100
# 0.3860858257199403 alpha=0.5 beta=2 q0=0.3 epochs=10 ants=4 W=1
# 0.382811533735808 alpha=0.5 beta=2 q0=0.3 epochs=10 ants=4 W=10
# 0.3867707108427957 alpha=0.5 beta=2 q0=0.3 epochs=10 ants=4 W=100
# 0.33784873822904354 alpha=0.5 beta=2 q0=0.3 epochs=10 ants=10 W=1
# 0.3474917114594168 alpha=0.5 beta=2 q0=0.3 epochs=10 ants=10 W=10
# 0.3367021868142158 alpha=0.5 beta=2 q0=0.3 epochs=10 ants=10 W=100
# 0.3747591614940322 alpha=0.5 beta=2 q0=0.4 epochs=4 ants=4 W=1
# 0.36749401472407084 alpha=0.5 beta=2 q0=0.4 epochs=4 ants=4 W=10
# 0.38183864117423216 alpha=0.5 beta=2 q0=0.4 epochs=4 ants=4 W=100
# 0.3352431908266086 alpha=0.5 beta=2 q0=0.4 epochs=4 ants=10 W=1
# 0.33160823441909126 alpha=0.5 beta=2 q0=0.4 epochs=4 ants=10 W=10
# 0.3251397465305132 alpha=0.5 beta=2 q0=0.4 epochs=4 ants=10 W=100
# 0.35331719098130754 alpha=0.5 beta=2 q0=0.4 epochs=10 ants=4 W=1
# 0.3528632256405902 alpha=0.5 beta=2 q0=0.4 epochs=10 ants=4 W=10
# 0.33667181780109984 alpha=0.5 beta=2 q0=0.4 epochs=10 ants=4 W=100
# 0.3190720492595871 alpha=0.5 beta=2 q0=0.4 epochs=10 ants=10 W=1
# 0.30949613043609475 alpha=0.5 beta=2 q0=0.4 epochs=10 ants=10 W=10
# 0.30151380814749207 alpha=0.5 beta=2 q0=0.4 epochs=10 ants=10 W=100
# 0.3462775978263806 alpha=0.5 beta=2 q0=0.5 epochs=4 ants=4 W=1
# 0.3478072790870501 alpha=0.5 beta=2 q0=0.5 epochs=4 ants=4 W=10
# 0.3340927986146264 alpha=0.5 beta=2 q0=0.5 epochs=4 ants=4 W=100
# 0.3074594421116449 alpha=0.5 beta=2 q0=0.5 epochs=4 ants=10 W=1
# 0.30761957196773637 alpha=0.5 beta=2 q0=0.5 epochs=4 ants=10 W=10
# 0.2978585847183843 alpha=0.5 beta=2 q0=0.5 epochs=4 ants=10 W=100
# 0.3205320737244479 alpha=0.5 beta=2 q0=0.5 epochs=10 ants=4 W=1
# 0.3143915603536289 alpha=0.5 beta=2 q0=0.5 epochs=10 ants=4 W=10
# 0.3047001716887429 alpha=0.5 beta=2 q0=0.5 epochs=10 ants=4 W=100
# 0.29114966830338973 alpha=0.5 beta=2 q0=0.5 epochs=10 ants=10 W=1
# 0.2858816808595353 alpha=0.5 beta=2 q0=0.5 epochs=10 ants=10 W=10
# 0.27595851082321954 alpha=0.5 beta=2 q0=0.5 epochs=10 ants=10 W=100
# 0.2794519486751904 alpha=0.5 beta=2 q0=0.7 epochs=4 ants=4 W=1
# 0.27523599176783853 alpha=0.5 beta=2 q0=0.7 epochs=4 ants=4 W=10
# 0.27406325850256485 alpha=0.5 beta=2 q0=0.7 epochs=4 ants=4 W=100
# 0.23482597665754054 alpha=0.5 beta=2 q0=0.7 epochs=4 ants=10 W=1
# 0.23998368435099163 alpha=0.5 beta=2 q0=0.7 epochs=4 ants=10 W=10
# 0.24132987935523437 alpha=0.5 beta=2 q0=0.7 epochs=4 ants=10 W=100
# 0.2526417360357272 alpha=0.5 beta=2 q0=0.7 epochs=10 ants=4 W=1
# 0.2513504737877377 alpha=0.5 beta=2 q0=0.7 epochs=10 ants=4 W=10
# 0.2502184570400197 alpha=0.5 beta=2 q0=0.7 epochs=10 ants=4 W=100
# 0.22483056103290885 alpha=0.5 beta=2 q0=0.7 epochs=10 ants=10 W=1
# 0.22041162743832024 alpha=0.5 beta=2 q0=0.7 epochs=10 ants=10 W=10
# 0.21944119447776303 alpha=0.5 beta=2 q0=0.7 epochs=10 ants=10 W=100
# 0.22533043860573282 alpha=0.5 beta=2 q0=0.9 epochs=4 ants=4 W=1
# 0.23381348795348258 alpha=0.5 beta=2 q0=0.9 epochs=4 ants=4 W=10
# 0.22717049226705663 alpha=0.5 beta=2 q0=0.9 epochs=4 ants=4 W=100
# 0.20943904552976925 alpha=0.5 beta=2 q0=0.9 epochs=4 ants=10 W=1
# 0.19899715319633562 alpha=0.5 beta=2 q0=0.9 epochs=4 ants=10 W=10
# 0.2030331536335184 alpha=0.5 beta=2 q0=0.9 epochs=4 ants=10 W=100
# 0.22315990972360836 alpha=0.5 beta=2 q0=0.9 epochs=10 ants=4 W=1
# 0.19691496913770998 alpha=0.5 beta=2 q0=0.9 epochs=10 ants=4 W=10
# 0.21060271754512835 alpha=0.5 beta=2 q0=0.9 epochs=10 ants=4 W=100
# 0.1948880331688568 alpha=0.5 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.19473869032010158 alpha=0.5 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.18753259415439366 alpha=0.5 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.6819091715992855 alpha=0.6 beta=1 q0=0.3 epochs=4 ants=4 W=1
# 0.6847302045598551 alpha=0.6 beta=1 q0=0.3 epochs=4 ants=4 W=10
# 0.6963402968764554 alpha=0.6 beta=1 q0=0.3 epochs=4 ants=4 W=100
# 0.6175454267893581 alpha=0.6 beta=1 q0=0.3 epochs=4 ants=10 W=1
# 0.6284475760488706 alpha=0.6 beta=1 q0=0.3 epochs=4 ants=10 W=10
# 0.6329832733223921 alpha=0.6 beta=1 q0=0.3 epochs=4 ants=10 W=100
# 0.6464542036000772 alpha=0.6 beta=1 q0=0.3 epochs=10 ants=4 W=1
# 0.6271877135120583 alpha=0.6 beta=1 q0=0.3 epochs=10 ants=4 W=10
# 0.6607582288419913 alpha=0.6 beta=1 q0=0.3 epochs=10 ants=4 W=100
# 0.5879799896112937 alpha=0.6 beta=1 q0=0.3 epochs=10 ants=10 W=1
# 0.5921144317151128 alpha=0.6 beta=1 q0=0.3 epochs=10 ants=10 W=10
# 0.5771269269668269 alpha=0.6 beta=1 q0=0.3 epochs=10 ants=10 W=100
# 0.584348616694896 alpha=0.6 beta=1 q0=0.4 epochs=4 ants=4 W=1
# 0.6104467218572956 alpha=0.6 beta=1 q0=0.4 epochs=4 ants=4 W=10
# 0.5965817177102568 alpha=0.6 beta=1 q0=0.4 epochs=4 ants=4 W=100
# 0.5376033324384349 alpha=0.6 beta=1 q0=0.4 epochs=4 ants=10 W=1
# 0.5466143232404082 alpha=0.6 beta=1 q0=0.4 epochs=4 ants=10 W=10
# 0.5541640661644086 alpha=0.6 beta=1 q0=0.4 epochs=4 ants=10 W=100
# 0.565714862359702 alpha=0.6 beta=1 q0=0.4 epochs=10 ants=4 W=1
# 0.5758546622456971 alpha=0.6 beta=1 q0=0.4 epochs=10 ants=4 W=10
# 0.5502424496441789 alpha=0.6 beta=1 q0=0.4 epochs=10 ants=4 W=100
# 0.5132396872825197 alpha=0.6 beta=1 q0=0.4 epochs=10 ants=10 W=1
# 0.5102865770842123 alpha=0.6 beta=1 q0=0.4 epochs=10 ants=10 W=10
# 0.504602304859663 alpha=0.6 beta=1 q0=0.4 epochs=10 ants=10 W=100
# 0.5218977844777944 alpha=0.6 beta=1 q0=0.5 epochs=4 ants=4 W=1
# 0.5209816944050616 alpha=0.6 beta=1 q0=0.5 epochs=4 ants=4 W=10
# 0.5236814080047402 alpha=0.6 beta=1 q0=0.5 epochs=4 ants=4 W=100
# 0.48056185623409997 alpha=0.6 beta=1 q0=0.5 epochs=4 ants=10 W=1
# 0.47792531333400223 alpha=0.6 beta=1 q0=0.5 epochs=4 ants=10 W=10
# 0.46748031497452897 alpha=0.6 beta=1 q0=0.5 epochs=4 ants=10 W=100
# 0.47977500250651856 alpha=0.6 beta=1 q0=0.5 epochs=10 ants=4 W=1
# 0.49857736423017884 alpha=0.6 beta=1 q0=0.5 epochs=10 ants=4 W=10
# 0.489004316480375 alpha=0.6 beta=1 q0=0.5 epochs=10 ants=4 W=100
# 0.44093395026767007 alpha=0.6 beta=1 q0=0.5 epochs=10 ants=10 W=1
# 0.4389098221046334 alpha=0.6 beta=1 q0=0.5 epochs=10 ants=10 W=10
# 0.44329673203550607 alpha=0.6 beta=1 q0=0.5 epochs=10 ants=10 W=100
# 0.3690737766873665 alpha=0.6 beta=1 q0=0.7 epochs=4 ants=4 W=1
# 0.37260766035693377 alpha=0.6 beta=1 q0=0.7 epochs=4 ants=4 W=10
# 0.36619372517230914 alpha=0.6 beta=1 q0=0.7 epochs=4 ants=4 W=100
# 0.32715198186661376 alpha=0.6 beta=1 q0=0.7 epochs=4 ants=10 W=1
# 0.33593842629185233 alpha=0.6 beta=1 q0=0.7 epochs=4 ants=10 W=10
# 0.32146218900720036 alpha=0.6 beta=1 q0=0.7 epochs=4 ants=10 W=100
# 0.34654265783486893 alpha=0.6 beta=1 q0=0.7 epochs=10 ants=4 W=1
# 0.3486417313776929 alpha=0.6 beta=1 q0=0.7 epochs=10 ants=4 W=10
# 0.33667580178697193 alpha=0.6 beta=1 q0=0.7 epochs=10 ants=4 W=100
# 0.3100791334385423 alpha=0.6 beta=1 q0=0.7 epochs=10 ants=10 W=1
# 0.3063513139845479 alpha=0.6 beta=1 q0=0.7 epochs=10 ants=10 W=10
# 0.31528526092372816 alpha=0.6 beta=1 q0=0.7 epochs=10 ants=10 W=100
# 0.25913573423321085 alpha=0.6 beta=1 q0=0.9 epochs=4 ants=4 W=1
# 0.2544733437843493 alpha=0.6 beta=1 q0=0.9 epochs=4 ants=4 W=10
# 0.2535800957080842 alpha=0.6 beta=1 q0=0.9 epochs=4 ants=4 W=100
# 0.22762155222147545 alpha=0.6 beta=1 q0=0.9 epochs=4 ants=10 W=1
# 0.22928130348269402 alpha=0.6 beta=1 q0=0.9 epochs=4 ants=10 W=10
# 0.22832248273906408 alpha=0.6 beta=1 q0=0.9 epochs=4 ants=10 W=100
# 0.24866265252855774 alpha=0.6 beta=1 q0=0.9 epochs=10 ants=4 W=1
# 0.24142804432055381 alpha=0.6 beta=1 q0=0.9 epochs=10 ants=4 W=10
# 0.23812956548820682 alpha=0.6 beta=1 q0=0.9 epochs=10 ants=4 W=100
# 0.2252302628162331 alpha=0.6 beta=1 q0=0.9 epochs=10 ants=10 W=1
# 0.21535005258873194 alpha=0.6 beta=1 q0=0.9 epochs=10 ants=10 W=10
# 0.21796848366381427 alpha=0.6 beta=1 q0=0.9 epochs=10 ants=10 W=100
# 0.4223537363883849 alpha=0.6 beta=2 q0=0.3 epochs=4 ants=4 W=1
# 0.42262322901569493 alpha=0.6 beta=2 q0=0.3 epochs=4 ants=4 W=10
# 0.4150520318020001 alpha=0.6 beta=2 q0=0.3 epochs=4 ants=4 W=100
# 0.3727600970889939 alpha=0.6 beta=2 q0=0.3 epochs=4 ants=10 W=1
# 0.37503506119810065 alpha=0.6 beta=2 q0=0.3 epochs=4 ants=10 W=10
# 0.3773114012538428 alpha=0.6 beta=2 q0=0.3 epochs=4 ants=10 W=100
# 0.3899717221362248 alpha=0.6 beta=2 q0=0.3 epochs=10 ants=4 W=1
# 0.3862459793702892 alpha=0.6 beta=2 q0=0.3 epochs=10 ants=4 W=10
# 0.3901065497530652 alpha=0.6 beta=2 q0=0.3 epochs=10 ants=4 W=100
# 0.34498523241107926 alpha=0.6 beta=2 q0=0.3 epochs=10 ants=10 W=1
# 0.3448050487048804 alpha=0.6 beta=2 q0=0.3 epochs=10 ants=10 W=10
# 0.35084899834711386 alpha=0.6 beta=2 q0=0.3 epochs=10 ants=10 W=100
# 0.3703951063758186 alpha=0.6 beta=2 q0=0.4 epochs=4 ants=4 W=1
# 0.371099622156165 alpha=0.6 beta=2 q0=0.4 epochs=4 ants=4 W=10
# 0.38487155712832416 alpha=0.6 beta=2 q0=0.4 epochs=4 ants=4 W=100
# 0.33934909953761727 alpha=0.6 beta=2 q0=0.4 epochs=4 ants=10 W=1
# 0.34434556070821215 alpha=0.6 beta=2 q0=0.4 epochs=4 ants=10 W=10
# 0.343995234768893 alpha=0.6 beta=2 q0=0.4 epochs=4 ants=10 W=100
# 0.3592638758734316 alpha=0.6 beta=2 q0=0.4 epochs=10 ants=4 W=1
# 0.35622794738984426 alpha=0.6 beta=2 q0=0.4 epochs=10 ants=4 W=10
# 0.3557051153287424 alpha=0.6 beta=2 q0=0.4 epochs=10 ants=4 W=100
# 0.31620558306347346 alpha=0.6 beta=2 q0=0.4 epochs=10 ants=10 W=1
# 0.30642495421989113 alpha=0.6 beta=2 q0=0.4 epochs=10 ants=10 W=10
# 0.30403234577658594 alpha=0.6 beta=2 q0=0.4 epochs=10 ants=10 W=100
# 0.3429425316869251 alpha=0.6 beta=2 q0=0.5 epochs=4 ants=4 W=1
# 0.3491183504906923 alpha=0.6 beta=2 q0=0.5 epochs=4 ants=4 W=10
# 0.33624495321676856 alpha=0.6 beta=2 q0=0.5 epochs=4 ants=4 W=100
# 0.29874714918364387 alpha=0.6 beta=2 q0=0.5 epochs=4 ants=10 W=1
# 0.30644877042517044 alpha=0.6 beta=2 q0=0.5 epochs=4 ants=10 W=10
# 0.30588681934006584 alpha=0.6 beta=2 q0=0.5 epochs=4 ants=10 W=100
# 0.3117070787151603 alpha=0.6 beta=2 q0=0.5 epochs=10 ants=4 W=1
# 0.3125266130997797 alpha=0.6 beta=2 q0=0.5 epochs=10 ants=4 W=10
# 0.3132553583777632 alpha=0.6 beta=2 q0=0.5 epochs=10 ants=4 W=100
# 0.2826389711960432 alpha=0.6 beta=2 q0=0.5 epochs=10 ants=10 W=1
# 0.2834282470825266 alpha=0.6 beta=2 q0=0.5 epochs=10 ants=10 W=10
# 0.27465387368680305 alpha=0.6 beta=2 q0=0.5 epochs=10 ants=10 W=100
# 0.27882304650192896 alpha=0.6 beta=2 q0=0.7 epochs=4 ants=4 W=1
# 0.2780669031830935 alpha=0.6 beta=2 q0=0.7 epochs=4 ants=4 W=10
# 0.27981571298466884 alpha=0.6 beta=2 q0=0.7 epochs=4 ants=4 W=100
# 0.24634802535224765 alpha=0.6 beta=2 q0=0.7 epochs=4 ants=10 W=1
# 0.24468629305524736 alpha=0.6 beta=2 q0=0.7 epochs=4 ants=10 W=10
# 0.2439890501055107 alpha=0.6 beta=2 q0=0.7 epochs=4 ants=10 W=100
# 0.255698176621938 alpha=0.6 beta=2 q0=0.7 epochs=10 ants=4 W=1
# 0.2558822886731982 alpha=0.6 beta=2 q0=0.7 epochs=10 ants=4 W=10
# 0.2602810695486484 alpha=0.6 beta=2 q0=0.7 epochs=10 ants=4 W=100
# 0.23174276898118568 alpha=0.6 beta=2 q0=0.7 epochs=10 ants=10 W=1
# 0.2282328372659232 alpha=0.6 beta=2 q0=0.7 epochs=10 ants=10 W=10
# 0.23021026416368745 alpha=0.6 beta=2 q0=0.7 epochs=10 ants=10 W=100
# 0.23272833586562622 alpha=0.6 beta=2 q0=0.9 epochs=4 ants=4 W=1
# 0.22101237487065936 alpha=0.6 beta=2 q0=0.9 epochs=4 ants=4 W=10
# 0.22081115947389304 alpha=0.6 beta=2 q0=0.9 epochs=4 ants=4 W=100
# 0.20208056445848405 alpha=0.6 beta=2 q0=0.9 epochs=4 ants=10 W=1
# 0.20635388564464716 alpha=0.6 beta=2 q0=0.9 epochs=4 ants=10 W=10
# 0.20017282844897527 alpha=0.6 beta=2 q0=0.9 epochs=4 ants=10 W=100
# 0.20752979129438895 alpha=0.6 beta=2 q0=0.9 epochs=10 ants=4 W=1
# 0.20583668670096344 alpha=0.6 beta=2 q0=0.9 epochs=10 ants=4 W=10
# 0.20429483602867346 alpha=0.6 beta=2 q0=0.9 epochs=10 ants=4 W=100
# 0.1900783880976288 alpha=0.6 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.19156561147342044 alpha=0.6 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.18793030020323293 alpha=0.6 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.6932336470558476 alpha=0.7 beta=1 q0=0.3 epochs=4 ants=4 W=1
# 0.6954405131086303 alpha=0.7 beta=1 q0=0.3 epochs=4 ants=4 W=10
# 0.6730655722892475 alpha=0.7 beta=1 q0=0.3 epochs=4 ants=4 W=100
# 0.6256869191459723 alpha=0.7 beta=1 q0=0.3 epochs=4 ants=10 W=1
# 0.6297881028548281 alpha=0.7 beta=1 q0=0.3 epochs=4 ants=10 W=10
# 0.6342614863253032 alpha=0.7 beta=1 q0=0.3 epochs=4 ants=10 W=100
# 0.6451401637170988 alpha=0.7 beta=1 q0=0.3 epochs=10 ants=4 W=1
# 0.6557397871080769 alpha=0.7 beta=1 q0=0.3 epochs=10 ants=4 W=10
# 0.6419374506334311 alpha=0.7 beta=1 q0=0.3 epochs=10 ants=4 W=100
# 0.6096928548255661 alpha=0.7 beta=1 q0=0.3 epochs=10 ants=10 W=1
# 0.6024966483713958 alpha=0.7 beta=1 q0=0.3 epochs=10 ants=10 W=10
# 0.5811039437042633 alpha=0.7 beta=1 q0=0.3 epochs=10 ants=10 W=100
# 0.6289163846625675 alpha=0.7 beta=1 q0=0.4 epochs=4 ants=4 W=1
# 0.6072196195474933 alpha=0.7 beta=1 q0=0.4 epochs=4 ants=4 W=10
# 0.5991946510523984 alpha=0.7 beta=1 q0=0.4 epochs=4 ants=4 W=100
# 0.5448581254496797 alpha=0.7 beta=1 q0=0.4 epochs=4 ants=10 W=1
# 0.5367264943833786 alpha=0.7 beta=1 q0=0.4 epochs=4 ants=10 W=10
# 0.5611424503839693 alpha=0.7 beta=1 q0=0.4 epochs=4 ants=10 W=100
# 0.593295830394187 alpha=0.7 beta=1 q0=0.4 epochs=10 ants=4 W=1
# 0.5604095480914253 alpha=0.7 beta=1 q0=0.4 epochs=10 ants=4 W=10
# 0.5566943341591738 alpha=0.7 beta=1 q0=0.4 epochs=10 ants=4 W=100
# 0.5147815953464083 alpha=0.7 beta=1 q0=0.4 epochs=10 ants=10 W=1
# 0.5091033152518745 alpha=0.7 beta=1 q0=0.4 epochs=10 ants=10 W=10
# 0.4964904578718779 alpha=0.7 beta=1 q0=0.4 epochs=10 ants=10 W=100
# 0.5288389362229029 alpha=0.7 beta=1 q0=0.5 epochs=4 ants=4 W=1
# 0.548288035226294 alpha=0.7 beta=1 q0=0.5 epochs=4 ants=4 W=10
# 0.5220083841352318 alpha=0.7 beta=1 q0=0.5 epochs=4 ants=4 W=100
# 0.48002719447424647 alpha=0.7 beta=1 q0=0.5 epochs=4 ants=10 W=1
# 0.47270321118249714 alpha=0.7 beta=1 q0=0.5 epochs=4 ants=10 W=10
# 0.4669940521772958 alpha=0.7 beta=1 q0=0.5 epochs=4 ants=10 W=100
# 0.5026433378018442 alpha=0.7 beta=1 q0=0.5 epochs=10 ants=4 W=1
# 0.4979903373281266 alpha=0.7 beta=1 q0=0.5 epochs=10 ants=4 W=10
# 0.4846198473783392 alpha=0.7 beta=1 q0=0.5 epochs=10 ants=4 W=100
# 0.4387505899272837 alpha=0.7 beta=1 q0=0.5 epochs=10 ants=10 W=1
# 0.4448391357257707 alpha=0.7 beta=1 q0=0.5 epochs=10 ants=10 W=10
# 0.42425499468894057 alpha=0.7 beta=1 q0=0.5 epochs=10 ants=10 W=100
# 0.39296218543582195 alpha=0.7 beta=1 q0=0.7 epochs=4 ants=4 W=1
# 0.37333773012533894 alpha=0.7 beta=1 q0=0.7 epochs=4 ants=4 W=10
# 0.37476788232385283 alpha=0.7 beta=1 q0=0.7 epochs=4 ants=4 W=100
# 0.3438668778017218 alpha=0.7 beta=1 q0=0.7 epochs=4 ants=10 W=1
# 0.3324728704453629 alpha=0.7 beta=1 q0=0.7 epochs=4 ants=10 W=10
# 0.3342599764594964 alpha=0.7 beta=1 q0=0.7 epochs=4 ants=10 W=100
# 0.35329459108355094 alpha=0.7 beta=1 q0=0.7 epochs=10 ants=4 W=1
# 0.35029706788215925 alpha=0.7 beta=1 q0=0.7 epochs=10 ants=4 W=10
# 0.35447900543566074 alpha=0.7 beta=1 q0=0.7 epochs=10 ants=4 W=100
# 0.31858238379612375 alpha=0.7 beta=1 q0=0.7 epochs=10 ants=10 W=1
# 0.3158264038826687 alpha=0.7 beta=1 q0=0.7 epochs=10 ants=10 W=10
# 0.31115901694011666 alpha=0.7 beta=1 q0=0.7 epochs=10 ants=10 W=100
# 0.2626959668727086 alpha=0.7 beta=1 q0=0.9 epochs=4 ants=4 W=1
# 0.2620872746261661 alpha=0.7 beta=1 q0=0.9 epochs=4 ants=4 W=10
# 0.2518872104799819 alpha=0.7 beta=1 q0=0.9 epochs=4 ants=4 W=100
# 0.2292865797922296 alpha=0.7 beta=1 q0=0.9 epochs=4 ants=10 W=1
# 0.2230444722241116 alpha=0.7 beta=1 q0=0.9 epochs=4 ants=10 W=10
# 0.22441920009819846 alpha=0.7 beta=1 q0=0.9 epochs=4 ants=10 W=100
# 0.25925885918556507 alpha=0.7 beta=1 q0=0.9 epochs=10 ants=4 W=1
# 0.2511822427876378 alpha=0.7 beta=1 q0=0.9 epochs=10 ants=4 W=10
# 0.2542013431144128 alpha=0.7 beta=1 q0=0.9 epochs=10 ants=4 W=100
# 0.21535681411135524 alpha=0.7 beta=1 q0=0.9 epochs=10 ants=10 W=1
# 0.22951469782690553 alpha=0.7 beta=1 q0=0.9 epochs=10 ants=10 W=10
# 0.2185643772352138 alpha=0.7 beta=1 q0=0.9 epochs=10 ants=10 W=100
# 0.42133199382966213 alpha=0.7 beta=2 q0=0.3 epochs=4 ants=4 W=1
# 0.41772740658862495 alpha=0.7 beta=2 q0=0.3 epochs=4 ants=4 W=10
# 0.409222209666792 alpha=0.7 beta=2 q0=0.3 epochs=4 ants=4 W=100
# 0.38683175097698363 alpha=0.7 beta=2 q0=0.3 epochs=4 ants=10 W=1
# 0.3511241694772013 alpha=0.7 beta=2 q0=0.3 epochs=4 ants=10 W=10
# 0.3737011789740393 alpha=0.7 beta=2 q0=0.3 epochs=4 ants=10 W=100
# 0.38682421291416275 alpha=0.7 beta=2 q0=0.3 epochs=10 ants=4 W=1
# 0.3871090485662553 alpha=0.7 beta=2 q0=0.3 epochs=10 ants=4 W=10
# 0.3867275889705157 alpha=0.7 beta=2 q0=0.3 epochs=10 ants=4 W=100
# 0.3531938260946498 alpha=0.7 beta=2 q0=0.3 epochs=10 ants=10 W=1
# 0.3549554758683295 alpha=0.7 beta=2 q0=0.3 epochs=10 ants=10 W=10
# 0.34838745103496027 alpha=0.7 beta=2 q0=0.3 epochs=10 ants=10 W=100
# 0.3778674583027279 alpha=0.7 beta=2 q0=0.4 epochs=4 ants=4 W=1
# 0.38307955484082107 alpha=0.7 beta=2 q0=0.4 epochs=4 ants=4 W=10
# 0.37072695467603695 alpha=0.7 beta=2 q0=0.4 epochs=4 ants=4 W=100
# 0.3485060285332021 alpha=0.7 beta=2 q0=0.4 epochs=4 ants=10 W=1
# 0.3302132379742898 alpha=0.7 beta=2 q0=0.4 epochs=4 ants=10 W=10
# 0.3445997463792347 alpha=0.7 beta=2 q0=0.4 epochs=4 ants=10 W=100
# 0.35300528814026355 alpha=0.7 beta=2 q0=0.4 epochs=10 ants=4 W=1
# 0.3519235641659297 alpha=0.7 beta=2 q0=0.4 epochs=10 ants=4 W=10
# 0.33976244256908483 alpha=0.7 beta=2 q0=0.4 epochs=10 ants=4 W=100
# 0.3173563947504739 alpha=0.7 beta=2 q0=0.4 epochs=10 ants=10 W=1
# 0.3107573731383448 alpha=0.7 beta=2 q0=0.4 epochs=10 ants=10 W=10
# 0.3134104307541027 alpha=0.7 beta=2 q0=0.4 epochs=10 ants=10 W=100
# 0.34688971067810936 alpha=0.7 beta=2 q0=0.5 epochs=4 ants=4 W=1
# 0.3540685034395122 alpha=0.7 beta=2 q0=0.5 epochs=4 ants=4 W=10
# 0.34788669435575703 alpha=0.7 beta=2 q0=0.5 epochs=4 ants=4 W=100
# 0.30420102462035886 alpha=0.7 beta=2 q0=0.5 epochs=4 ants=10 W=1
# 0.29225869491283346 alpha=0.7 beta=2 q0=0.5 epochs=4 ants=10 W=10
# 0.2979307680305549 alpha=0.7 beta=2 q0=0.5 epochs=4 ants=10 W=100
# 0.3174750838232298 alpha=0.7 beta=2 q0=0.5 epochs=10 ants=4 W=1
# 0.30823222004424855 alpha=0.7 beta=2 q0=0.5 epochs=10 ants=4 W=10
# 0.3064042533275197 alpha=0.7 beta=2 q0=0.5 epochs=10 ants=4 W=100
# 0.28702881409507364 alpha=0.7 beta=2 q0=0.5 epochs=10 ants=10 W=1
# 0.28271268956968126 alpha=0.7 beta=2 q0=0.5 epochs=10 ants=10 W=10
# 0.2800918870289028 alpha=0.7 beta=2 q0=0.5 epochs=10 ants=10 W=100
# 0.28091911568846195 alpha=0.7 beta=2 q0=0.7 epochs=4 ants=4 W=1
# 0.27694946042821844 alpha=0.7 beta=2 q0=0.7 epochs=4 ants=4 W=10
# 0.28160491743183336 alpha=0.7 beta=2 q0=0.7 epochs=4 ants=4 W=100
# 0.2465695526559294 alpha=0.7 beta=2 q0=0.7 epochs=4 ants=10 W=1
# 0.2517353511862088 alpha=0.7 beta=2 q0=0.7 epochs=4 ants=10 W=10
# 0.2424006043298385 alpha=0.7 beta=2 q0=0.7 epochs=4 ants=10 W=100
# 0.2582897674151365 alpha=0.7 beta=2 q0=0.7 epochs=10 ants=4 W=1
# 0.2591270924033465 alpha=0.7 beta=2 q0=0.7 epochs=10 ants=4 W=10
# 0.26052138000072284 alpha=0.7 beta=2 q0=0.7 epochs=10 ants=4 W=100
# 0.23207255922819695 alpha=0.7 beta=2 q0=0.7 epochs=10 ants=10 W=1
# 0.2372880574921286 alpha=0.7 beta=2 q0=0.7 epochs=10 ants=10 W=10
# 0.22647867382781603 alpha=0.7 beta=2 q0=0.7 epochs=10 ants=10 W=100
# 0.22779992386623313 alpha=0.7 beta=2 q0=0.9 epochs=4 ants=4 W=1
# 0.23302096575501843 alpha=0.7 beta=2 q0=0.9 epochs=4 ants=4 W=10
# 0.22146919562238698 alpha=0.7 beta=2 q0=0.9 epochs=4 ants=4 W=100
# 0.20526910613137653 alpha=0.7 beta=2 q0=0.9 epochs=4 ants=10 W=1
# 0.19788486487506807 alpha=0.7 beta=2 q0=0.9 epochs=4 ants=10 W=10
# 0.20404667442116836 alpha=0.7 beta=2 q0=0.9 epochs=4 ants=10 W=100
# 0.21848274768836612 alpha=0.7 beta=2 q0=0.9 epochs=10 ants=4 W=1
# 0.2091781213345661 alpha=0.7 beta=2 q0=0.9 epochs=10 ants=4 W=10
# 0.21349990541139782 alpha=0.7 beta=2 q0=0.9 epochs=10 ants=4 W=100
# 0.19623501098500087 alpha=0.7 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.189437357050333 alpha=0.7 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.18802198022439703 alpha=0.7 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.7062635651280222 alpha=0.8 beta=1 q0=0.3 epochs=4 ants=4 W=1
# 0.7208570054836713 alpha=0.8 beta=1 q0=0.3 epochs=4 ants=4 W=10
# 0.6925729325187162 alpha=0.8 beta=1 q0=0.3 epochs=4 ants=4 W=100
# 0.6478958207991334 alpha=0.8 beta=1 q0=0.3 epochs=4 ants=10 W=1
# 0.6267514656450587 alpha=0.8 beta=1 q0=0.3 epochs=4 ants=10 W=10
# 0.6303564524442673 alpha=0.8 beta=1 q0=0.3 epochs=4 ants=10 W=100
# 0.6373620642697155 alpha=0.8 beta=1 q0=0.3 epochs=10 ants=4 W=1
# 0.659280067060759 alpha=0.8 beta=1 q0=0.3 epochs=10 ants=4 W=10
# 0.6586915477294626 alpha=0.8 beta=1 q0=0.3 epochs=10 ants=4 W=100
# 0.5972872200475983 alpha=0.8 beta=1 q0=0.3 epochs=10 ants=10 W=1
# 0.594954552796678 alpha=0.8 beta=1 q0=0.3 epochs=10 ants=10 W=10
# 0.5927813514554315 alpha=0.8 beta=1 q0=0.3 epochs=10 ants=10 W=100
# 0.6212395428220214 alpha=0.8 beta=1 q0=0.4 epochs=4 ants=4 W=1
# 0.6064234868530202 alpha=0.8 beta=1 q0=0.4 epochs=4 ants=4 W=10
# 0.6121569215225109 alpha=0.8 beta=1 q0=0.4 epochs=4 ants=4 W=100
# 0.5584446184481808 alpha=0.8 beta=1 q0=0.4 epochs=4 ants=10 W=1
# 0.5515331622645782 alpha=0.8 beta=1 q0=0.4 epochs=4 ants=10 W=10
# 0.5410890854241258 alpha=0.8 beta=1 q0=0.4 epochs=4 ants=10 W=100
# 0.5784740538981388 alpha=0.8 beta=1 q0=0.4 epochs=10 ants=4 W=1
# 0.5604752276157684 alpha=0.8 beta=1 q0=0.4 epochs=10 ants=4 W=10
# 0.5664722521891974 alpha=0.8 beta=1 q0=0.4 epochs=10 ants=4 W=100
# 0.5296456095971025 alpha=0.8 beta=1 q0=0.4 epochs=10 ants=10 W=1
# 0.5124400448891807 alpha=0.8 beta=1 q0=0.4 epochs=10 ants=10 W=10
# 0.5237618519253634 alpha=0.8 beta=1 q0=0.4 epochs=10 ants=10 W=100
# 0.5224667127619633 alpha=0.8 beta=1 q0=0.5 epochs=4 ants=4 W=1
# 0.5463005861751243 alpha=0.8 beta=1 q0=0.5 epochs=4 ants=4 W=10
# 0.5352324594644193 alpha=0.8 beta=1 q0=0.5 epochs=4 ants=4 W=100
# 0.48054111423587514 alpha=0.8 beta=1 q0=0.5 epochs=4 ants=10 W=1
# 0.4696299161098919 alpha=0.8 beta=1 q0=0.5 epochs=4 ants=10 W=10
# 0.45957444503218337 alpha=0.8 beta=1 q0=0.5 epochs=4 ants=10 W=100
# 0.502610653918463 alpha=0.8 beta=1 q0=0.5 epochs=10 ants=4 W=1
# 0.5043973691963084 alpha=0.8 beta=1 q0=0.5 epochs=10 ants=4 W=10
# 0.4999548778044318 alpha=0.8 beta=1 q0=0.5 epochs=10 ants=4 W=100
# 0.4545352746027525 alpha=0.8 beta=1 q0=0.5 epochs=10 ants=10 W=1
# 0.44795376578242496 alpha=0.8 beta=1 q0=0.5 epochs=10 ants=10 W=10
# 0.4399629128718054 alpha=0.8 beta=1 q0=0.5 epochs=10 ants=10 W=100
# 0.40065531964605905 alpha=0.8 beta=1 q0=0.7 epochs=4 ants=4 W=1
# 0.3795313164242925 alpha=0.8 beta=1 q0=0.7 epochs=4 ants=4 W=10
# 0.3755756868771548 alpha=0.8 beta=1 q0=0.7 epochs=4 ants=4 W=100
# 0.34199581031891413 alpha=0.8 beta=1 q0=0.7 epochs=4 ants=10 W=1
# 0.33725481364943555 alpha=0.8 beta=1 q0=0.7 epochs=4 ants=10 W=10
# 0.3361605587895587 alpha=0.8 beta=1 q0=0.7 epochs=4 ants=10 W=100
# 0.3710117844051807 alpha=0.8 beta=1 q0=0.7 epochs=10 ants=4 W=1
# 0.367815403204859 alpha=0.8 beta=1 q0=0.7 epochs=10 ants=4 W=10
# 0.3641238748067447 alpha=0.8 beta=1 q0=0.7 epochs=10 ants=4 W=100
# 0.3282018318509034 alpha=0.8 beta=1 q0=0.7 epochs=10 ants=10 W=1
# 0.3255953853845009 alpha=0.8 beta=1 q0=0.7 epochs=10 ants=10 W=10
# 0.31422598062003637 alpha=0.8 beta=1 q0=0.7 epochs=10 ants=10 W=100
# 0.2548330195395092 alpha=0.8 beta=1 q0=0.9 epochs=4 ants=4 W=1
# 0.26653247807370656 alpha=0.8 beta=1 q0=0.9 epochs=4 ants=4 W=10
# 0.25204446483898413 alpha=0.8 beta=1 q0=0.9 epochs=4 ants=4 W=100
# 0.23785911690610773 alpha=0.8 beta=1 q0=0.9 epochs=4 ants=10 W=1
# 0.22758165578285888 alpha=0.8 beta=1 q0=0.9 epochs=4 ants=10 W=10
# 0.22947511030078607 alpha=0.8 beta=1 q0=0.9 epochs=4 ants=10 W=100
# 0.24893761539721607 alpha=0.8 beta=1 q0=0.9 epochs=10 ants=4 W=1
# 0.25379512095556334 alpha=0.8 beta=1 q0=0.9 epochs=10 ants=4 W=10
# 0.25366652938447054 alpha=0.8 beta=1 q0=0.9 epochs=10 ants=4 W=100
# 0.23276962255899508 alpha=0.8 beta=1 q0=0.9 epochs=10 ants=10 W=1
# 0.22028583982190272 alpha=0.8 beta=1 q0=0.9 epochs=10 ants=10 W=10
# 0.2132166519938374 alpha=0.8 beta=1 q0=0.9 epochs=10 ants=10 W=100
# 0.4245029338064154 alpha=0.8 beta=2 q0=0.3 epochs=4 ants=4 W=1
# 0.41528136904853613 alpha=0.8 beta=2 q0=0.3 epochs=4 ants=4 W=10
# 0.42358317578486726 alpha=0.8 beta=2 q0=0.3 epochs=4 ants=4 W=100
# 0.37702438383258213 alpha=0.8 beta=2 q0=0.3 epochs=4 ants=10 W=1
# 0.38184854660631495 alpha=0.8 beta=2 q0=0.3 epochs=4 ants=10 W=10
# 0.37431355177776243 alpha=0.8 beta=2 q0=0.3 epochs=4 ants=10 W=100
# 0.4089817626659172 alpha=0.8 beta=2 q0=0.3 epochs=10 ants=4 W=1
# 0.3955200251420796 alpha=0.8 beta=2 q0=0.3 epochs=10 ants=4 W=10
# 0.3794507510355622 alpha=0.8 beta=2 q0=0.3 epochs=10 ants=4 W=100
# 0.3550040741353765 alpha=0.8 beta=2 q0=0.3 epochs=10 ants=10 W=1
# 0.35785449347182063 alpha=0.8 beta=2 q0=0.3 epochs=10 ants=10 W=10
# 0.34586587157937065 alpha=0.8 beta=2 q0=0.3 epochs=10 ants=10 W=100
# 0.3920148907548055 alpha=0.8 beta=2 q0=0.4 epochs=4 ants=4 W=1
# 0.3822138189648074 alpha=0.8 beta=2 q0=0.4 epochs=4 ants=4 W=10
# 0.3859458682593167 alpha=0.8 beta=2 q0=0.4 epochs=4 ants=4 W=100
# 0.33759609202056234 alpha=0.8 beta=2 q0=0.4 epochs=4 ants=10 W=1
# 0.3376784908543504 alpha=0.8 beta=2 q0=0.4 epochs=4 ants=10 W=10
# 0.34969667543250593 alpha=0.8 beta=2 q0=0.4 epochs=4 ants=10 W=100
# 0.36016210601284115 alpha=0.8 beta=2 q0=0.4 epochs=10 ants=4 W=1
# 0.3570455557168667 alpha=0.8 beta=2 q0=0.4 epochs=10 ants=4 W=10
# 0.35218544999909923 alpha=0.8 beta=2 q0=0.4 epochs=10 ants=4 W=100
# 0.3198562245618274 alpha=0.8 beta=2 q0=0.4 epochs=10 ants=10 W=1
# 0.3201853951750043 alpha=0.8 beta=2 q0=0.4 epochs=10 ants=10 W=10
# 0.3166515286825805 alpha=0.8 beta=2 q0=0.4 epochs=10 ants=10 W=100
# 0.35274719662196613 alpha=0.8 beta=2 q0=0.5 epochs=4 ants=4 W=1
# 0.3443151566834626 alpha=0.8 beta=2 q0=0.5 epochs=4 ants=4 W=10
# 0.34688508428322873 alpha=0.8 beta=2 q0=0.5 epochs=4 ants=4 W=100
# 0.31846917262511215 alpha=0.8 beta=2 q0=0.5 epochs=4 ants=10 W=1
# 0.3162162488656088 alpha=0.8 beta=2 q0=0.5 epochs=4 ants=10 W=10
# 0.3124334207064689 alpha=0.8 beta=2 q0=0.5 epochs=4 ants=10 W=100
# 0.32367183639106795 alpha=0.8 beta=2 q0=0.5 epochs=10 ants=4 W=1
# 0.3290588209885133 alpha=0.8 beta=2 q0=0.5 epochs=10 ants=4 W=10
# 0.31524256881407614 alpha=0.8 beta=2 q0=0.5 epochs=10 ants=4 W=100
# 0.2881044910623817 alpha=0.8 beta=2 q0=0.5 epochs=10 ants=10 W=1
# 0.28777790615570537 alpha=0.8 beta=2 q0=0.5 epochs=10 ants=10 W=10
# 0.27649394972265906 alpha=0.8 beta=2 q0=0.5 epochs=10 ants=10 W=100
# 0.28656498721039386 alpha=0.8 beta=2 q0=0.7 epochs=4 ants=4 W=1
# 0.28198092496338223 alpha=0.8 beta=2 q0=0.7 epochs=4 ants=4 W=10
# 0.27465314164487364 alpha=0.8 beta=2 q0=0.7 epochs=4 ants=4 W=100
# 0.25132043413385846 alpha=0.8 beta=2 q0=0.7 epochs=4 ants=10 W=1
# 0.2530891513906655 alpha=0.8 beta=2 q0=0.7 epochs=4 ants=10 W=10
# 0.24654624515994653 alpha=0.8 beta=2 q0=0.7 epochs=4 ants=10 W=100
# 0.2662194539621321 alpha=0.8 beta=2 q0=0.7 epochs=10 ants=4 W=1
# 0.2603621125823866 alpha=0.8 beta=2 q0=0.7 epochs=10 ants=4 W=10
# 0.25830431828318806 alpha=0.8 beta=2 q0=0.7 epochs=10 ants=4 W=100
# 0.2350127429930495 alpha=0.8 beta=2 q0=0.7 epochs=10 ants=10 W=1
# 0.2322096778328957 alpha=0.8 beta=2 q0=0.7 epochs=10 ants=10 W=10
# 0.22981324539094547 alpha=0.8 beta=2 q0=0.7 epochs=10 ants=10 W=100
# 0.2389014017307414 alpha=0.8 beta=2 q0=0.9 epochs=4 ants=4 W=1
# 0.22901332292805113 alpha=0.8 beta=2 q0=0.9 epochs=4 ants=4 W=10
# 0.23234072875672718 alpha=0.8 beta=2 q0=0.9 epochs=4 ants=4 W=100
# 0.20323545260589915 alpha=0.8 beta=2 q0=0.9 epochs=4 ants=10 W=1
# 0.21158838201730193 alpha=0.8 beta=2 q0=0.9 epochs=4 ants=10 W=10
# 0.20889022242304853 alpha=0.8 beta=2 q0=0.9 epochs=4 ants=10 W=100
# 0.22211806581463722 alpha=0.8 beta=2 q0=0.9 epochs=10 ants=4 W=1
# 0.21522418310147573 alpha=0.8 beta=2 q0=0.9 epochs=10 ants=4 W=10
# 0.21272360364101625 alpha=0.8 beta=2 q0=0.9 epochs=10 ants=4 W=100
# 0.19864663445117492 alpha=0.8 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.19668491711770866 alpha=0.8 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.1899964266528606 alpha=0.8 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.6962768924355677 alpha=0.9 beta=1 q0=0.3 epochs=4 ants=4 W=1
# 0.6781704706085011 alpha=0.9 beta=1 q0=0.3 epochs=4 ants=4 W=10
# 0.6906585585012351 alpha=0.9 beta=1 q0=0.3 epochs=4 ants=4 W=100
# 0.6520441591400847 alpha=0.9 beta=1 q0=0.3 epochs=4 ants=10 W=1
# 0.6482569465257744 alpha=0.9 beta=1 q0=0.3 epochs=4 ants=10 W=10
# 0.6284012412807651 alpha=0.9 beta=1 q0=0.3 epochs=4 ants=10 W=100
# 0.6641224734800716 alpha=0.9 beta=1 q0=0.3 epochs=10 ants=4 W=1
# 0.6623139259441371 alpha=0.9 beta=1 q0=0.3 epochs=10 ants=4 W=10
# 0.6474860268800916 alpha=0.9 beta=1 q0=0.3 epochs=10 ants=4 W=100
# 0.5987739748867641 alpha=0.9 beta=1 q0=0.3 epochs=10 ants=10 W=1
# 0.5867599724636907 alpha=0.9 beta=1 q0=0.3 epochs=10 ants=10 W=10
# 0.6069450199261549 alpha=0.9 beta=1 q0=0.3 epochs=10 ants=10 W=100
# 0.6126265557490311 alpha=0.9 beta=1 q0=0.4 epochs=4 ants=4 W=1
# 0.6198209919098493 alpha=0.9 beta=1 q0=0.4 epochs=4 ants=4 W=10
# 0.6152519890645511 alpha=0.9 beta=1 q0=0.4 epochs=4 ants=4 W=100
# 0.5445764702199974 alpha=0.9 beta=1 q0=0.4 epochs=4 ants=10 W=1
# 0.5665782594447357 alpha=0.9 beta=1 q0=0.4 epochs=4 ants=10 W=10
# 0.5405341831774123 alpha=0.9 beta=1 q0=0.4 epochs=4 ants=10 W=100
# 0.5842018144055098 alpha=0.9 beta=1 q0=0.4 epochs=10 ants=4 W=1
# 0.5805591899557284 alpha=0.9 beta=1 q0=0.4 epochs=10 ants=4 W=10
# 0.5984820908279872 alpha=0.9 beta=1 q0=0.4 epochs=10 ants=4 W=100
# 0.5248904418869881 alpha=0.9 beta=1 q0=0.4 epochs=10 ants=10 W=1
# 0.5180121458159563 alpha=0.9 beta=1 q0=0.4 epochs=10 ants=10 W=10
# 0.5176188765750096 alpha=0.9 beta=1 q0=0.4 epochs=10 ants=10 W=100
# 0.5339711829964026 alpha=0.9 beta=1 q0=0.5 epochs=4 ants=4 W=1
# 0.5278432834353688 alpha=0.9 beta=1 q0=0.5 epochs=4 ants=4 W=10
# 0.5310971799747005 alpha=0.9 beta=1 q0=0.5 epochs=4 ants=4 W=100
# 0.4841462617352458 alpha=0.9 beta=1 q0=0.5 epochs=4 ants=10 W=1
# 0.4898505478504026 alpha=0.9 beta=1 q0=0.5 epochs=4 ants=10 W=10
# 0.473036284133461 alpha=0.9 beta=1 q0=0.5 epochs=4 ants=10 W=100
# 0.5105295845959898 alpha=0.9 beta=1 q0=0.5 epochs=10 ants=4 W=1
# 0.4993387533570473 alpha=0.9 beta=1 q0=0.5 epochs=10 ants=4 W=10
# 0.5034549697044671 alpha=0.9 beta=1 q0=0.5 epochs=10 ants=4 W=100
# 0.4568184609746596 alpha=0.9 beta=1 q0=0.5 epochs=10 ants=10 W=1
# 0.4518028081692683 alpha=0.9 beta=1 q0=0.5 epochs=10 ants=10 W=10
# 0.4449524881460387 alpha=0.9 beta=1 q0=0.5 epochs=10 ants=10 W=100
# 0.40215238644381374 alpha=0.9 beta=1 q0=0.7 epochs=4 ants=4 W=1
# 0.38954986109231543 alpha=0.9 beta=1 q0=0.7 epochs=4 ants=4 W=10
# 0.3687662939682364 alpha=0.9 beta=1 q0=0.7 epochs=4 ants=4 W=100
# 0.33994629706982293 alpha=0.9 beta=1 q0=0.7 epochs=4 ants=10 W=1
# 0.3403933236548479 alpha=0.9 beta=1 q0=0.7 epochs=4 ants=10 W=10
# 0.3319176291319518 alpha=0.9 beta=1 q0=0.7 epochs=4 ants=10 W=100
# 0.3781498321784229 alpha=0.9 beta=1 q0=0.7 epochs=10 ants=4 W=1
# 0.3684247366357785 alpha=0.9 beta=1 q0=0.7 epochs=10 ants=4 W=10
# 0.35673998829868026 alpha=0.9 beta=1 q0=0.7 epochs=10 ants=4 W=100
# 0.3224696598408055 alpha=0.9 beta=1 q0=0.7 epochs=10 ants=10 W=1
# 0.32400443680658725 alpha=0.9 beta=1 q0=0.7 epochs=10 ants=10 W=10
# 0.31923040342156683 alpha=0.9 beta=1 q0=0.7 epochs=10 ants=10 W=100
# 0.26841342575351135 alpha=0.9 beta=1 q0=0.9 epochs=4 ants=4 W=1
# 0.2766323512957281 alpha=0.9 beta=1 q0=0.9 epochs=4 ants=4 W=10
# 0.25720935813220724 alpha=0.9 beta=1 q0=0.9 epochs=4 ants=4 W=100
# 0.23827484381044545 alpha=0.9 beta=1 q0=0.9 epochs=4 ants=10 W=1
# 0.23298717027828958 alpha=0.9 beta=1 q0=0.9 epochs=4 ants=10 W=10
# 0.22853847059161098 alpha=0.9 beta=1 q0=0.9 epochs=4 ants=10 W=100
# 0.2566411984941351 alpha=0.9 beta=1 q0=0.9 epochs=10 ants=4 W=1
# 0.2576192617364341 alpha=0.9 beta=1 q0=0.9 epochs=10 ants=4 W=10
# 0.24996880026008028 alpha=0.9 beta=1 q0=0.9 epochs=10 ants=4 W=100
# 0.22199267978159892 alpha=0.9 beta=1 q0=0.9 epochs=10 ants=10 W=1
# 0.23138711886048505 alpha=0.9 beta=1 q0=0.9 epochs=10 ants=10 W=10
# 0.21666297741191318 alpha=0.9 beta=1 q0=0.9 epochs=10 ants=10 W=100
# 0.4199040729756184 alpha=0.9 beta=2 q0=0.3 epochs=4 ants=4 W=1
# 0.4325811794291277 alpha=0.9 beta=2 q0=0.3 epochs=4 ants=4 W=10
# 0.42521692608200634 alpha=0.9 beta=2 q0=0.3 epochs=4 ants=4 W=100
# 0.38546049406600563 alpha=0.9 beta=2 q0=0.3 epochs=4 ants=10 W=1
# 0.38517665012367247 alpha=0.9 beta=2 q0=0.3 epochs=4 ants=10 W=10
# 0.3795887439452342 alpha=0.9 beta=2 q0=0.3 epochs=4 ants=10 W=100
# 0.3957253316154066 alpha=0.9 beta=2 q0=0.3 epochs=10 ants=4 W=1
# 0.38970501983903943 alpha=0.9 beta=2 q0=0.3 epochs=10 ants=4 W=10
# 0.4000629973808795 alpha=0.9 beta=2 q0=0.3 epochs=10 ants=4 W=100
# 0.36088808967209246 alpha=0.9 beta=2 q0=0.3 epochs=10 ants=10 W=1
# 0.3525279249884006 alpha=0.9 beta=2 q0=0.3 epochs=10 ants=10 W=10
# 0.35618268494346167 alpha=0.9 beta=2 q0=0.3 epochs=10 ants=10 W=100
# 0.394119627865507 alpha=0.9 beta=2 q0=0.4 epochs=4 ants=4 W=1
# 0.39288623156866537 alpha=0.9 beta=2 q0=0.4 epochs=4 ants=4 W=10
# 0.3850290538420825 alpha=0.9 beta=2 q0=0.4 epochs=4 ants=4 W=100
# 0.3418877160298803 alpha=0.9 beta=2 q0=0.4 epochs=4 ants=10 W=1
# 0.3496263644195609 alpha=0.9 beta=2 q0=0.4 epochs=4 ants=10 W=10
# 0.339015111228249 alpha=0.9 beta=2 q0=0.4 epochs=4 ants=10 W=100
# 0.3581627650551494 alpha=0.9 beta=2 q0=0.4 epochs=10 ants=4 W=1
# 0.3580028151176445 alpha=0.9 beta=2 q0=0.4 epochs=10 ants=4 W=10
# 0.3618634447383113 alpha=0.9 beta=2 q0=0.4 epochs=10 ants=4 W=100
# 0.3201103263478436 alpha=0.9 beta=2 q0=0.4 epochs=10 ants=10 W=1
# 0.3252345509254115 alpha=0.9 beta=2 q0=0.4 epochs=10 ants=10 W=10
# 0.3153550427633739 alpha=0.9 beta=2 q0=0.4 epochs=10 ants=10 W=100
# 0.3481571890027872 alpha=0.9 beta=2 q0=0.5 epochs=4 ants=4 W=1
# 0.34108546207610063 alpha=0.9 beta=2 q0=0.5 epochs=4 ants=4 W=10
# 0.3469878682206088 alpha=0.9 beta=2 q0=0.5 epochs=4 ants=4 W=100
# 0.3078071587612538 alpha=0.9 beta=2 q0=0.5 epochs=4 ants=10 W=1
# 0.3170074464878495 alpha=0.9 beta=2 q0=0.5 epochs=4 ants=10 W=10
# 0.31151166629994237 alpha=0.9 beta=2 q0=0.5 epochs=4 ants=10 W=100
# 0.31638593769995815 alpha=0.9 beta=2 q0=0.5 epochs=10 ants=4 W=1
# 0.3382216255737764 alpha=0.9 beta=2 q0=0.5 epochs=10 ants=4 W=10
# 0.3294243607359691 alpha=0.9 beta=2 q0=0.5 epochs=10 ants=4 W=100
# 0.3044082109182143 alpha=0.9 beta=2 q0=0.5 epochs=10 ants=10 W=1
# 0.3044344149308194 alpha=0.9 beta=2 q0=0.5 epochs=10 ants=10 W=10
# 0.2839875237494078 alpha=0.9 beta=2 q0=0.5 epochs=10 ants=10 W=100
# 0.2935862735666594 alpha=0.9 beta=2 q0=0.7 epochs=4 ants=4 W=1
# 0.28130509308495893 alpha=0.9 beta=2 q0=0.7 epochs=4 ants=4 W=10
# 0.2816437870125779 alpha=0.9 beta=2 q0=0.7 epochs=4 ants=4 W=100
# 0.2536382731920614 alpha=0.9 beta=2 q0=0.7 epochs=4 ants=10 W=1
# 0.2566148935263048 alpha=0.9 beta=2 q0=0.7 epochs=4 ants=10 W=10
# 0.2527098472104312 alpha=0.9 beta=2 q0=0.7 epochs=4 ants=10 W=100
# 0.27159315514543625 alpha=0.9 beta=2 q0=0.7 epochs=10 ants=4 W=1
# 0.2628381229953749 alpha=0.9 beta=2 q0=0.7 epochs=10 ants=4 W=10
# 0.2631271800407236 alpha=0.9 beta=2 q0=0.7 epochs=10 ants=4 W=100
# 0.23987836568828771 alpha=0.9 beta=2 q0=0.7 epochs=10 ants=10 W=1
# 0.2391714301817291 alpha=0.9 beta=2 q0=0.7 epochs=10 ants=10 W=10
# 0.232758807171071 alpha=0.9 beta=2 q0=0.7 epochs=10 ants=10 W=100
# 0.23626464752028103 alpha=0.9 beta=2 q0=0.9 epochs=4 ants=4 W=1
# 0.23886839585497793 alpha=0.9 beta=2 q0=0.9 epochs=4 ants=4 W=10
# 0.22983209697022428 alpha=0.9 beta=2 q0=0.9 epochs=4 ants=4 W=100
# 0.20376989682521876 alpha=0.9 beta=2 q0=0.9 epochs=4 ants=10 W=1
# 0.20527343847933302 alpha=0.9 beta=2 q0=0.9 epochs=4 ants=10 W=10
# 0.2069043128943347 alpha=0.9 beta=2 q0=0.9 epochs=4 ants=10 W=100
# 0.22884847221545007 alpha=0.9 beta=2 q0=0.9 epochs=10 ants=4 W=1
# 0.2300783712550437 alpha=0.9 beta=2 q0=0.9 epochs=10 ants=4 W=10
# 0.22025073225742856 alpha=0.9 beta=2 q0=0.9 epochs=10 ants=4 W=100
# 0.1984362599360128 alpha=0.9 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.20279622656033142 alpha=0.9 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.1908712619619969 alpha=0.9 beta=2 q0=0.9 epochs=10 ants=10 W=100

# %%
min_1 = np.min(list(scores.values()))
sc1 = list(scores.keys())[np.argmin(list(scores.values()))]
min_1, sc1
# Out:
# (np.float64(0.18435543032666538),
#  'alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=1')

# %%
q0 = [0.9, 1]
alpha = [0.1, 0.2, 0.3]
beta = [2]
epochs=[10]
W = [1, 10, 100]
ants = [10]

scores = dict()
for a in alpha:
    for b in beta:
        for q in q0:
            for e in epochs:
                for an in ants:
                    for w in W:
                        differences = []
                        for prefix in files:
                            aco = ACOUnifiedVRP(
                                alpha=a,  
                                beta=b, 
                                q0=q,  
                                epochs=e,  
                                num_ants=an,
                                W=w
                            )
                            aco.fit(prefix, verbose=True)
                            rel_error = aco.evaluate_solution()
                            differences.append(rel_error)
                        scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'] = np.mean(differences)
                        print(scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'], f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}')
# Out:
# 0.1832183234049641 alpha=0.1 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.18257535140266637 alpha=0.1 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.1831155163623455 alpha=0.1 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.23772462959789548 alpha=0.1 beta=2 q0=1 epochs=10 ants=10 W=1
# 0.24109678414680485 alpha=0.1 beta=2 q0=1 epochs=10 ants=10 W=10
# 0.24433504571794548 alpha=0.1 beta=2 q0=1 epochs=10 ants=10 W=100
# 0.18539168509618348 alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.17896948007944286 alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.1841604715697144 alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.2399340574976667 alpha=0.2 beta=2 q0=1 epochs=10 ants=10 W=1
# 0.24040021002198608 alpha=0.2 beta=2 q0=1 epochs=10 ants=10 W=10
# 0.24492226049241925 alpha=0.2 beta=2 q0=1 epochs=10 ants=10 W=100
# 0.1875048344060148 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.18281801233711562 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.18368580327317247 alpha=0.3 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.25091889082386826 alpha=0.3 beta=2 q0=1 epochs=10 ants=10 W=1
# 0.25254744418146635 alpha=0.3 beta=2 q0=1 epochs=10 ants=10 W=10
# 0.25163516288158455 alpha=0.3 beta=2 q0=1 epochs=10 ants=10 W=100

# %%
min_1 = np.min(list(scores.values()))
sc1 = list(scores.keys())[np.argmin(list(scores.values()))]
min_1, sc1
# Out:
# (np.float64(0.17896948007944286),
#  'alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=10')

# %%
q0 = [0.9]
alpha = [0.1, 0.2]
beta = [2, 3, 5]
epochs=[10]
W = [1, 10, 100]
ants = [10]

scores = dict()
for a in alpha:
    for b in beta:
        for q in q0:
            for e in epochs:
                for an in ants:
                    for w in W:
                        differences = []
                        for prefix in files:
                            aco = ACOUnifiedVRP(
                                alpha=a,  
                                beta=b, 
                                q0=q,  
                                epochs=e,  
                                num_ants=an,
                                W=w
                            )
                            aco.fit(prefix, verbose=True)
                            rel_error = aco.evaluate_solution()
                            differences.append(rel_error)
                        scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'] = np.mean(differences)
                        print(scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'], f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}')
# Out:
# 0.1820232588534395 alpha=0.1 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.18298890454569355 alpha=0.1 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.18466183657259602 alpha=0.1 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.17707779655253036 alpha=0.1 beta=3 q0=0.9 epochs=10 ants=10 W=1
# 0.1751714947169089 alpha=0.1 beta=3 q0=0.9 epochs=10 ants=10 W=10
# 0.17404218511527056 alpha=0.1 beta=3 q0=0.9 epochs=10 ants=10 W=100
# 0.17381611454750162 alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=1
# 0.17918160173791245 alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=10
# 0.1800357217153351 alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=100
# 0.18709089039059554 alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=1
# 0.18484047551740537 alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=10
# 0.18467560912896946 alpha=0.2 beta=2 q0=0.9 epochs=10 ants=10 W=100
# 0.18212710533290116 alpha=0.2 beta=3 q0=0.9 epochs=10 ants=10 W=1
# 0.18470970539224077 alpha=0.2 beta=3 q0=0.9 epochs=10 ants=10 W=10
# 0.18117649651784568 alpha=0.2 beta=3 q0=0.9 epochs=10 ants=10 W=100
# 0.18039263873842212 alpha=0.2 beta=5 q0=0.9 epochs=10 ants=10 W=1
# 0.18212801767092554 alpha=0.2 beta=5 q0=0.9 epochs=10 ants=10 W=10
# 0.1816084458693812 alpha=0.2 beta=5 q0=0.9 epochs=10 ants=10 W=100

# %%
min_1 = np.min(list(scores.values()))
sc1 = list(scores.keys())[np.argmin(list(scores.values()))]
min_1, sc1
# Out:
# (np.float64(0.17381611454750162),
#  'alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=1')

# %%
q0 = [0.9]
alpha = [0.1]
beta = [4, 5]
epochs=[10]
W = [1, 10, 100]
ants = [10]

scores = dict()
for a in alpha:
    for b in beta:
        for q in q0:
            for e in epochs:
                for an in ants:
                    for w in W:
                        differences = []
                        for prefix in files:
                            aco = ACOUnifiedVRP(
                                alpha=a,  
                                beta=b, 
                                q0=q,  
                                epochs=e,  
                                num_ants=an,
                                W=w
                            )
                            aco.fit(prefix, verbose=True)
                            rel_error = aco.evaluate_solution()
                            differences.append(rel_error)
                        scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'] = np.mean(differences)
                        print(scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'], f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}')
# Out:
# 0.1785535030329675 alpha=0.1 beta=4 q0=0.9 epochs=10 ants=10 W=1
# 0.17993578298979793 alpha=0.1 beta=4 q0=0.9 epochs=10 ants=10 W=10
# 0.17731435858993863 alpha=0.1 beta=4 q0=0.9 epochs=10 ants=10 W=100
# 0.180383549052264 alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=1
# 0.17626027559833973 alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=10
# 0.17367271143770638 alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=100

# %%
min_1 = np.min(list(scores.values()))
sc1 = list(scores.keys())[np.argmin(list(scores.values()))]
min_1, sc1
# Out:
# (np.float64(0.17367271143770638),
#  'alpha=0.1 beta=5 q0=0.9 epochs=10 ants=10 W=100')

# %%
q0 = [0.7]
alpha = [0.1, 0.3]
beta = [2, 5]
epochs=[50]
W = [0, 10, 20]
ants = [20]

scores = dict()
for a in alpha:
    for b in beta:
        for q in q0:
            for e in epochs:
                for an in ants:
                    for w in W:
                        differences = []
                        for prefix in files:
                            aco = ACOUnifiedVRP(
                                alpha=a,  
                                beta=b, 
                                q0=q,  
                                epochs=e,  
                                num_ants=an,
                                W=w
                            )
                            aco.fit(prefix, verbose=True)
                            rel_error = aco.evaluate_solution()
                            differences.append(rel_error)
                        scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'] = np.mean(differences)
                        print(scores[f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}'], f'alpha={a} beta={b} q0={q} epochs={e} ants={an} W={w}')
# Out:
# 0.17629100083211868 alpha=0.1 beta=2 q0=0.7 epochs=50 ants=20 W=0
# 0.18036162588450325 alpha=0.1 beta=2 q0=0.7 epochs=50 ants=20 W=10
# 0.17842862603364099 alpha=0.1 beta=2 q0=0.7 epochs=50 ants=20 W=20
# 0.14353804564846656 alpha=0.1 beta=5 q0=0.7 epochs=50 ants=20 W=0
# 0.14492091388718442 alpha=0.1 beta=5 q0=0.7 epochs=50 ants=20 W=10
# 0.14238095206880572 alpha=0.1 beta=5 q0=0.7 epochs=50 ants=20 W=20
# 0.18148133431116104 alpha=0.3 beta=2 q0=0.7 epochs=50 ants=20 W=0
# 0.1777807730889296 alpha=0.3 beta=2 q0=0.7 epochs=50 ants=20 W=10
# 0.1810372703254334 alpha=0.3 beta=2 q0=0.7 epochs=50 ants=20 W=20
# 0.14375781557455067 alpha=0.3 beta=5 q0=0.7 epochs=50 ants=20 W=0
# 0.1456386049256843 alpha=0.3 beta=5 q0=0.7 epochs=50 ants=20 W=10
# 0.13820111981918287 alpha=0.3 beta=5 q0=0.7 epochs=50 ants=20 W=20

# %%
min_1 = np.min(list(scores.values()))
sc1 = list(scores.keys())[np.argmin(list(scores.values()))]
min_1, sc1
# Out:
# (np.float64(0.13820111981918287),
#  'alpha=0.3 beta=5 q0=0.7 epochs=50 ants=20 W=20')
